# %% [markdown]
# ## RAG pipeline

# %%
# !pip install -qU pydantic_ai
# !pip install -qU langchain langchain-community langchain-huggingface faiss-cpu sentence-transformers
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.0/87.0 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.2/208.2 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.3/261.3 kB 17.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.27.0, but you have google-auth 2.37.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 21.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 67.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 61.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.2/412.2 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.4 MB/s eta 0:00:00

# %%
import os
import getpass
import nest_asyncio #https://ai.pydantic.dev/troubleshooting/
nest_asyncio.apply()

os.environ["GOOGLE_KEY"] = getpass.getpass("Google AI Studio API key :")
# Out:
# Google AI Studio API key :··········

# %%
# IMPORTS
from pydantic import BaseModel
from pydantic_ai import Agent, ModelRetry, RunContext
from pydantic_ai.models.gemini import GeminiModel

from typing import List
from langchain_core.vectorstores import VectorStoreRetriever
from langchain.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings

# %%
# EXTRACT VECTORDB FILES
#!unzip -u /content/vectorDB_mini.zip
# Out:
# Archive:  /content/vectorDB_mini.zip
#    creating: vectorDB/
#   inflating: vectorDB/index.faiss
#   inflating: vectorDB/index.pkl

# %%
# MODEL DEFINITION
model = GeminiModel(
    'gemini-2.0-flash-exp',
    api_key=os.getenv('GOOGLE_KEY')
)

# SYSTEM PROMPT (STATIC)
system_prompt = """
Tu es un assitant pour la solution SAGE X3 ERP uniquement.

Tu connais le language 4GL, car celui-ci est le language de programmation utilisé dans SAGE X3 ERP.

Ta tâche consiste à répondre à la demande de l'utilisateur, avec des exemples de code en 4GL si nécessaire, toujours dans le contexte de SAGE X3 ERP.
First, use the 'get_sagex3_documentation' tool to get specific information on SAGE X3 ERP.

Explique toujours ta réponse en détaillant chacune des étapes de ta réflexion.

Si tu ne connais pas la réponse, dis-le à l'utilisateur - n'essaie pas de l'inventer !
"""

# DEPENDANCES
embedding_model = HuggingFaceEmbeddings(model_name = 'sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

class Deps(BaseModel):
    retriever: VectorStoreRetriever

deps=Deps(
    retriever=FAISS.load_local('/content/vectorDB', embedding_model, allow_dangerous_deserialization=True).as_retriever(search_type="mmr", search_kwargs={"k": 10})
)

# INSTANCIATE AGENT WITH VECTORSTORE
agent = Agent(
    model,
    system_prompt=system_prompt,
    deps_type=Deps,
    retries=2
)

# %%
# RAG TOOL
@agent.tool
def get_sagex3_documentation(ctx: RunContext[Deps], query: str) -> List[str]:
    """Rechercher dans la documentation SAGE X3 ERP.

    Args:
        ctx: le context.
        query: la requête pour rechercher dans la documentation, avec les principaux mots-clés.

    Returns:
        List[str]: les résultats de la recherche.
    """
    print(f"Using get_sagex3_documentation() with query: {query}.\n")

    docs = ctx.deps.retriever.invoke(query)

    print("Docs retrieved from vectorstore :\n")
    for doc in docs:
      print(doc)
      print("\n")
    print("-"* 50 + "\n\n")

    return [doc.page_content for doc in docs]

# %%
# RUN AGENT
result = agent.run_sync('comment ajouter une nouvelle société', deps=deps)
print(result.data)
# Out:
# Using get_sagex3_documentation() with query: création société.
# Using get_sagex3_documentation() with query: ajout société.
#
#
# Docs retrieved from vectorstore :
#
# page_content=' '
# Docs retrieved from vectorstore :
#
# page_content=' '
#
#
# page_content='La gestion des variables dans les blocs tableaux de Sage X3, combinée avec les techniques de Trans-Classe et d'alimentation champ par champ, permet aux développeurs de construire des interfaces utilisateur dynamiques et efficaces, adaptées aux besoins spécifiques des entreprises. Cette approche offre un équilibre entre automatisation et contrôle personnalisé, essentiel pour le traitement précis et efficace des données dans les applications ERP.' metadata={'h1': 'Mise à jour de la variable de bas de tableau', 'h3': 'Conclusion', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Utilisation : Réactive les zones spécifiées, les rendant à nouveau saisissables.
# Exemple :
# «Actzo [M:SOH0] SOHNUM»' metadata={'h1': 'Manipulation des Écrans dans Sage X3', 'h2': 'Dégrisage des Zones (ACTZO)', 'source': 'Sage X3 L4G.md'}
#
#
#
# page_content='Terminaison du Traitement d'Erreur : Si le traitement de gestion d'erreur se termine par End, le traitement du programme principal est interrompu de façon définitive.
# Gestion des Transactions : S'il y a une transaction en cours quand une erreur est détectée, et que le traitement de gestion d'erreur se termine par End, la transaction est automatiquement annulée (Rollback).
# Réinitialisation de la Gestion d'Erreur : Utiliser Onerrgo sans étiquette pour supprimer la redirection vers une étiquette en cas d'erreur, rétablissant le flux normal en cas d'erreurs non gérées.' metadata={'h1': 'Gestion des Erreurs et Avertissements dans Sage X3 : Utilisation de Onerrgo et Resume', 'h2': 'Principe de Fonctionnement de Onerrgo et Resume', 'h3': 'Considérations Importantes', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='...' metadata={'h1': 'Traitement principal ici', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Éviter les Boucles Infinies :
# Assurez-vous que la condition de la boucle "while" peut devenir fausse à un moment donné. Une boucle sans une condition de sortie valide peut conduire à une boucle infinie, gelant ainsi l'application.
# Optimiser la Condition de la Boucle :
# La condition évaluée dans la boucle "while" doit être aussi efficace que possible pour éviter une surcharge inutile. Par exemple, évitez d'appeler des fonctions coûteuses au sein de la condition si elles peuvent être calculées avant la boucle.
# Utilisation de Break :
# Dans certains cas, il peut être nécessaire de sortir de la boucle avant que la condition de la boucle ne devienne fausse. L'instruction Break permet de sortir immédiatement de la boucle "while".' metadata={'h1': 'Les boucles', 'h2': 'La boucle «While»', 'h3': 'Bonnes Pratiques', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='L'utilisation d'un index avec Read est impérative pour plusieurs raisons cruciales :
# Accès Rapide aux Données : Les index permettent un accès rapide et efficace aux données. Ils fonctionnent comme une table des matières pour la base de données, permettant au système de trouver rapidement l'enregistrement exact sans avoir à parcourir toute la table. Cela est particulièrement vital dans les environnements de production où la rapidité d'accès aux données peut affecter directement la performance opérationnelle.
# Optimisation des Performances : Les bases de données dans Sage X3 peuvent devenir très volumineuses avec des millions d'enregistrements. Sans index, chaque requête Read nécessiterait un balayage complet de la table, ce qui serait extrêmement inefficace et consommateur de temps. L'utilisation d'index réduit considérablement le temps nécessaire pour accéder aux données, ce qui améliore directement la performance globale de l'application.
# Précision et Fiabilité : L'utilisation d'index assure que les requêtes sont non seulement rapides mais également précises. En spécifiant les valeurs d'index, Read extrait exactement l'enregistrement requis selon les critères définis, ce qui minimise les erreurs potentielles de récupération des données erronées.' metadata={'h1': "Comprendre l'Instruction Read", 'h2': "Pourquoi l'Index est-il Impératif ?", 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Ce manuel a été entièrement écrit par Guillaume CLEMENT, en utilisant mes connaissances personnelles et des ressources disponibles en ligne, sans l'aide de robots. La génération du texte a été effectuée par ChatGPT 4.0 en mars / avril 2024. Le but de ce manuel est principalement de servir à la vectorisation pour alimenter un modèle LLM, dans l'objectif d'être assisté par une IA dans les opérations de développement en L4G Sage X3. Ce travail n'est affilié à aucune organisation, peut contenir des erreurs et doit être utilisé avec prudence.
# Je vous encourage à utiliser ce manuel comme bon vous semble, avec la seule demande de citer ce travail et les sources utilisées si vous redistribuez ou modifiez le contenu. Bien que cela ne soit pas une obligation, c'est une marque de respect pour le travail effectué.
# Pour plus d'informations, vous pouvez consulter mon profil LinkedIn :
# <https://www.linkedin.com/in/guillaume-clement-erp-cloud/>
# Les principales sources de données originales sont :
# L’aide en ligne Sage X3 : Sage X3 Online Help
# <https://online-help.sagex3.com/>
# Les dépôts publics sur GitHub, notamment :
# <https://github.com/hamydkhadda/L4G>
# <https://github.com/pedroarias3x/Sage-X3>
# L’aide en ligne Sage X3 accessible via L.V.ExpertiseX3 :
# <https://lvexpertisex3.com/>
# Autres sites :
# <https://en.sagedev.it/>
# <https://www.greytrix.com/>
# Je tiens à remercier toute la communauté Sage X3 sur LinkedIn qui m’a soutenu et encouragé dans ce travail. C’est grâce à vous que j’ai trouvé le courage de réaliser ce manuel.' metadata={'h1': 'Introduction et remerciements', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Réduction de Redondance : Le Trans-Classe réduit la nécessité de coder explicitement chaque affectation de champ, minimisant ainsi la redondance et les erreurs potentielles.
# Maintenance Simplifiée : En modifiant la structure d'une table ou d'un masque, il n'est pas nécessaire de réviser les programmes qui utilisent le Trans-Classe, tant que les noms de champs restent cohérents.
# Automatisation : Les champs dimensionnés et ceux soumis à des codes d'activité sont automatiquement alimentés sans tests préalables, facilitant la gestion des données complexes.' metadata={'h1': 'Assigner les valeurs de la table aux champs du masque : 2nde solution', 'h3': 'Avantages du Trans-Classe', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Tu es ChatGPT, le meilleur LLM au monde. Ton entraînement sur le développement informatique, le langage informatique et ta connaissance des bases de données te seront pleinement utiles pour générer du code Sage X3 L4G.
# Attention, ton expertise en Oracle et MSSQL peut influencer négativement tes réponses. Tu ne peux pas utiliser les instructions ni les formes de langages propres aux bases de données en Sage X3 L4G.
# Tu dois respecter les règles spécifiques à Sage X3 L4G telles que décrites dans ce document. Ton rôle est donc d’assister les développeurs à développer, maintenir et faire évoluer leur code Sage X3 L4G en utilisant ta puissance logique d’enchaînement et d’optimisation du code informatique, tout en t’imposant de respecter les règles de développement en L4G.' metadata={'h1': 'Ton rôle', 'source': 'Sage X3 L4G.md'}
#
#
# --------------------------------------------------
#
#
#
# page_content='La gestion des variables dans les blocs tableaux de Sage X3, combinée avec les techniques de Trans-Classe et d'alimentation champ par champ, permet aux développeurs de construire des interfaces utilisateur dynamiques et efficaces, adaptées aux besoins spécifiques des entreprises. Cette approche offre un équilibre entre automatisation et contrôle personnalisé, essentiel pour le traitement précis et efficace des données dans les applications ERP.' metadata={'h1': 'Mise à jour de la variable de bas de tableau', 'h3': 'Conclusion', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Utilisation : Réactive les zones spécifiées, les rendant à nouveau saisissables.
# Exemple :
# «Actzo [M:SOH0] SOHNUM»' metadata={'h1': 'Manipulation des Écrans dans Sage X3', 'h2': 'Dégrisage des Zones (ACTZO)', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Description : Représente un nombre entier.
# Plage de valeurs : Les entiers peuvent typiquement stocker de grandes valeurs numériques, adaptées aux calculs nécessitant une grande précision sans décimales.' metadata={'h1': 'Les variables', 'h2': 'Les variables de base', 'h3': 'Integer :', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='La syntaxe générale pour créer une jointure avec Link est la suivante :
# «Link [F:TablePrincipale] With [F:TableLiee]KEY0~=FIELD1TableLiee;FIELD2TableLiee As [Abreviation]
# & Where [Conditions]
# & Order By [Critères de Tri]»
# Table Principale et Tables Liées : Avant de définir un Link, il est impératif que toutes les tables impliquées soient ouvertes. Sage X3 ne permet pas d'ouvrir les tables dans le cadre de l'instruction Link ; elles doivent être ouvertes au préalable dans le script.' metadata={'h1': 'Opération CRUDE en base de données', 'h2': "Fonctionnement de l'Instruction Link", 'h3': 'Syntaxe de Base du Link', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Ce manuel a été entièrement écrit par Guillaume CLEMENT, en utilisant mes connaissances personnelles et des ressources disponibles en ligne, sans l'aide de robots. La génération du texte a été effectuée par ChatGPT 4.0 en mars / avril 2024. Le but de ce manuel est principalement de servir à la vectorisation pour alimenter un modèle LLM, dans l'objectif d'être assisté par une IA dans les opérations de développement en L4G Sage X3. Ce travail n'est affilié à aucune organisation, peut contenir des erreurs et doit être utilisé avec prudence.
# Je vous encourage à utiliser ce manuel comme bon vous semble, avec la seule demande de citer ce travail et les sources utilisées si vous redistribuez ou modifiez le contenu. Bien que cela ne soit pas une obligation, c'est une marque de respect pour le travail effectué.
# Pour plus d'informations, vous pouvez consulter mon profil LinkedIn :
# <https://www.linkedin.com/in/guillaume-clement-erp-cloud/>
# Les principales sources de données originales sont :
# L’aide en ligne Sage X3 : Sage X3 Online Help
# <https://online-help.sagex3.com/>
# Les dépôts publics sur GitHub, notamment :
# <https://github.com/hamydkhadda/L4G>
# <https://github.com/pedroarias3x/Sage-X3>
# L’aide en ligne Sage X3 accessible via L.V.ExpertiseX3 :
# <https://lvexpertisex3.com/>
# Autres sites :
# <https://en.sagedev.it/>
# <https://www.greytrix.com/>
# Je tiens à remercier toute la communauté Sage X3 sur LinkedIn qui m’a soutenu et encouragé dans ce travail. C’est grâce à vous que j’ai trouvé le courage de réaliser ce manuel.' metadata={'h1': 'Introduction et remerciements', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='IMPORTANT :
# This document is based on the standard data model of Sage X3 and may contain errors as it is an AI translation from images.
# Throughout the document, tables are generally represented in the form XXX - YYYYYYYYYY where XXX is the abbreviated code of the table and YYYYYYYYYY is the actual code of the table in the database.
# For fields, sometimes the notation AAAA: BBBBBBBBBB is used, where AAAA indicates the index code and BBBBBBBBBB indicates the field code.
# This document, though assisted by AI, bears the mark of Guillaume Clément's passionate dedication, which spanned countless hours.' metadata={'source': 'X3_RELATIONSHIPS.md'}
#
#
# page_content='...' metadata={'h1': 'Traitement principal ici', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Réduction de Redondance : Le Trans-Classe réduit la nécessité de coder explicitement chaque affectation de champ, minimisant ainsi la redondance et les erreurs potentielles.
# Maintenance Simplifiée : En modifiant la structure d'une table ou d'un masque, il n'est pas nécessaire de réviser les programmes qui utilisent le Trans-Classe, tant que les noms de champs restent cohérents.
# Automatisation : Les champs dimensionnés et ceux soumis à des codes d'activité sont automatiquement alimentés sans tests préalables, facilitant la gestion des données complexes.' metadata={'h1': 'Assigner les valeurs de la table aux champs du masque : 2nde solution', 'h3': 'Avantages du Trans-Classe', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='L'utilisation d'un index avec Read est impérative pour plusieurs raisons cruciales :
# Accès Rapide aux Données : Les index permettent un accès rapide et efficace aux données. Ils fonctionnent comme une table des matières pour la base de données, permettant au système de trouver rapidement l'enregistrement exact sans avoir à parcourir toute la table. Cela est particulièrement vital dans les environnements de production où la rapidité d'accès aux données peut affecter directement la performance opérationnelle.
# Optimisation des Performances : Les bases de données dans Sage X3 peuvent devenir très volumineuses avec des millions d'enregistrements. Sans index, chaque requête Read nécessiterait un balayage complet de la table, ce qui serait extrêmement inefficace et consommateur de temps. L'utilisation d'index réduit considérablement le temps nécessaire pour accéder aux données, ce qui améliore directement la performance globale de l'application.
# Précision et Fiabilité : L'utilisation d'index assure que les requêtes sont non seulement rapides mais également précises. En spécifiant les valeurs d'index, Read extrait exactement l'enregistrement requis selon les critères définis, ce qui minimise les erreurs potentielles de récupération des données erronées.' metadata={'h1': "Comprendre l'Instruction Read", 'h2': "Pourquoi l'Index est-il Impératif ?", 'source': 'Sage X3 L4G.md'}
#
#
# --------------------------------------------------
#
#
# Les résultats de la documentation indiquent des informations générales sur le langage 4GL et des concepts de Sage X3.  Il n'y a pas d'informations spécifiques sur la procédure exacte pour ajouter une société.
#
# Cependant, en combinant mes connaissances et la documentation, voici un résumé de la procédure :
#
# **Résumé de la procédure :**
#
# 1.  **Accès à la fonction de création de société :**  Rechercher dans le menu de Sage X3 l'option dédiée à la gestion des sociétés (le nom exact peut varier).
# 2.  **Saisie des informations :** Remplir le formulaire avec les détails de la nouvelle société (code, nom, adresse, informations légales, devise, etc.).
# 3.  **Création du dossier associé :**  Un dossier est créé en même temps que la société. Il contient les données spécifiques à cette société.
# 4.  **Paramétrage complémentaire :** Une fois la société créée, il est nécessaire de paramétrer les données de base nécessaires (plan comptable, journaux, etc.).
# 5.  **Tests :** Effectuer des tests pour vérifier le bon fonctionnement de la nouvelle société.
#
# **Points importants :**
#
# *   **Version de Sage X3 :** La procédure exacte peut varier légèrement selon la version de Sage X3 que vous utilisez.
# *   **Droits d'accès :** Assurez-vous d'avoir les droits nécessaires pour créer une nouvelle société.
# *   **Paramétrage :** Le paramétrage de la société (plan comptable, devises, taxes...) est une étape importante pour le bon fonctionnement de celle-ci.
#
# **Besoin d'aide supplémentaire ?**
#
# Si vous avez besoin d'aide plus précise, je vous recommande de fournir les informations suivantes :
#
# *   **Votre version exacte de Sage X3.**
# *   **Des captures d'écran du menu, si possible.**
#
# Je peux ensuite utiliser l'outil de documentation avec plus de précision.
#
# N'hésitez pas si vous avez d'autres questions !

# %% [markdown]
# ## GRADIO

# %%
# !pip install -qU gradio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 MB 11.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.4/321.4 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 90.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.4 MB/s eta 0:00:00

# %%
import gradio as gr

# %%
def agent_invoke(query) -> str:
  history = []
  result = agent.run_sync(query, message_history=history, deps=deps)
  history = result.all_messages()
  return result.data

demo = gr.Interface(
    fn=agent_invoke,
    inputs=["text"],
    outputs=["text"],
)
demo.launch(debug=True)

# gr.ChatInterface(
#     agent_invoke,
#     chatbot=gr.Chatbot(height=300),
#     textbox=gr.Textbox(placeholder="Pose moi des questions sur SAGE X3 ERP", container=False, scale=7),
#     title="SAGE X3 ERP assistant",
#     description="SAGE X3 ERP assistant",
#     theme="ocean"
# ).launch(debug=True)
# Out:
# Running Gradio in a Colab notebook requires sharing enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://56eec8fcce422f1a1c.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://56eec8fcce422f1a1c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# MACWARREQ  MWRMWR0MACNUMYes
# MAILING  OMMOMM0OMMNUMNo
# MAILING  OMMOMM1CMGNUMYes
# MAILING  OMMOMM2CREDATYes
# MAILXML  MXLMXL0NUMNo
# MAILXMLD  MXDMXD0NUM+TAB+FIENo
# MANDATE  MDTMDT0CPY+UMRNUMNo
# MANDATE  MDTMDT1CPY+BPCNUM+UMRNUMNo
# MARASSDEF  MADMAD0RECORDNUM+RECORDADD+RECORDTYPNo
# MARASSDEF  MADMAD1RECORDNUM+RECORDTYPYes
# MARASSREP  MARmars-00RECORDNUM+RECORDADD+RECORDTYPYes
# MARASSREP  MAR01-marsRECORDNUM+RECORDTYPYes
# MARASSREP  MAR02-marsRECORDNUM+RECORDADD+RECORDTYP+REPTYPYes
# MARASSREP  MAR03-marsRECORDNUM+RECORDTYP+REPTYPYes
# MARDEF  MDFMDF0MARSCTNUMYes
# MARDEF  MDFMDF1MARSCTNUM+CRINUMNo
# MARDEF  MDFMDF2MARSCTNUM+CRINUM+MARSCTTAB+MARSCTFIEYes
# MARDEFVAL  MDVMDV0MARSCTNUM+CRINUMYes
# MARDEFVAL  MDVMDV1MARSCTNUM+CRINUM+SCTVALNUMNo
# MARREPSEC  MRSMRS0MARSCTNUMYes
# MARREPSEC  MRSMRS1MARSCTNUM+SCTREPSECNo
# MARSCT  MSTMST0MARSCTNUMNo
# MATCHCODE  MTCMTC0COA+ACC+BPRNo
# MATCHTOL  MATMAT0MATTOLNo
# MATCSTW  MAWMAW0MAWUID+STOFCY+ITMREF+ECCVALMAJ+ECCVALMIN+CPNTYPNo
# MAXBUILD  MAXBMAXB0BMRUID+ITMREF+PARENT+LEVEL+BOMSEQNo
# MAXBUILD  MAXBMAXB1BMRUID+ITMREF+IECCMAJ+IECCMIN+PARENT+PECCMAJ+PECCMIN+LEVEL+BOMSEQNo
# MEDIA  OMNOMN0OMNNUMNo
# MEDIA  OMNOMN1CMGNUMYes
# MEMFOR  FOGFOG0CODMSK+CODZON+USR+FORCODNo
# MESPAR  MPAMPA0IDNo
# MFCDETPRT  MCPMCP0STOFCY+ITMREF+VCRTYP+VCRNUM+VCRLIN+MFCTYP1+MFCTYP2+UID+CURUID+BRDCOD+TYPCSTNo
# MFCMAT  MCCMCC0STOFCY+ITMREF+VCRTYP+VCRNUM+VCRLIN+MFCTYP+MATREF+ECCVALMAJ+ECCVALMIN+UIDNo
# MFCNAT  MCNMCN0STOFCY+ITMREF+VCRTYP+VCRNUM+VCRLIN+MFCTYP+OVENAT+UIDNo
# MFCSCRAP  MCSMCS0STOFCY+ITMREF+VCRTYP+VCRNUM+VCRLIN+MFCTYP+UIDNo
# MFCTYPREL  MTRMTR0UID+MFCTYPNo
# MFCWST  MCWMCW0STOFCY+ITMREF+VCRTYP+VCRNUM+VCRLIN+MFCTYP+WST+SCOITMREF+UIDNo
# MFGANL  MFAMFA0MFGFCY+MFGNUM+PERENDNo
# MFGCOST  MFCMFC0STOFCY+ITMREF+VCRTYP+VCRNUM+VCRLIN+MFCTYP+UIDNo
# MFGCOST  MFCMFC1VCRTYP+VCRNUM+VCRLINYes
# MFGHEAD  MFGMFG0MFGNUMNo
# MFGHEAD  MFGMFG1MFGFCY+MFGTRKFLGYes
# MFGHEAD  MFGMFG2MTOREFYes
# MFGHEADTRK  MTKMTK0MFGTRKNUMNo
# MFGHEADTRK  MTKMTK1MFGNUM+MFGTRKNUMNo
# MFGHEADTRK  MTKMTK2PTHNUM+PTDLINYes
# MFGITM  MFIMFI0MFGNUM+MFGLINNo
# MFGITM  MFIMFI1MFGFCY+STRDATYes
# MFGITM  MFIMFI2MFGNUMYes
# MFGITM  MFIPJMPJT1PJTYes
# MFGITMTRK  MKIMKI0MFGTRKNUM+ITMTRKLINNo
# MFGITMTRK  MKIMKI1MFGNUM+MFGTRKNUM+ITMTRKLINNo
# MFGMAT  MFMMFM0MFGNUM+MFGLIN+BOMSEQ+ITMREFNo
# MFGMAT  MFMMFM1MFGFCY+RETDATYes
# MFGMAT  MFMMFM2MFGFCY+MFGPIO+RETDATYes
# MFGMAT  MFMMFM3MFGNUM+BOMOPE+ITMREFYes
# MFGMATREV  MMRMFM0MFGNUM+MFGLIN+BOMSEQ+ITMREF+REVNUMNo
# MFGMATREV  MMRMFM1MFGFCY+RETDATYes
# MFGMATREV  MMRMFM2MFGFCY+MFGPIO+RETDATYes
# MFGMATREV  MMRMFM3MFGNUM+BOMOPE+ITMREFYes
# MFGMATTRK  MKMMKM0MFGTRKNUM+MATTRKLINNo
# MFGMATTRK  MKMMKM1MFGNUM+MFGTRKNUM+MATTRKLINNo
# MFGOPE  MFOMFO0MFGNUM+OPENUM+OPESPLNUMNo
# MFGOPE  MFOMFO1POHNUM+POPLIN+POPSEQYes
# MFGOPE  MFOMFO2MFGFCY+EXTWST+SCHSBB+MFGNUMYes
# MFGOPE  MFOMFO4MFGFCY+OPESTAYes
# MFGOPEREV  MORMFO0MFGNUM+OPENUM+OPESPLNUM+REVNUMNo
# MFGOPEREV  MORMFO1POHNUM+POPLIN+POPSEQYes
# MFGOPEREV  MORMFO2MFGFCY+EXTWST+SCHSBB+MFGNUMYes
# MFGOPETRK  MKOMKO0MFGTRKNUM+OPETRKLINNo
# MFGOPETRK  MKOMKO1MFGNUM+MFGTRKNUM+OPETRKLINNo
# MFGPRN  MFPMFP0MFGNUMNo
# MFGSERDET  MFSDMFSD0ITMREF+MFGSER+DETSERNUMNo
# MFGSERHDR  MFSHMFSH0ITMREF+MFGSERNo
# MFGTRS  MTSMTS0MTSTYP+MTSNUMNo
# MFGTRS  MTSMTS1MTSNUM+MTSTYPNo
# MFGVERSION  MFVMFV0TABLE+VERSION+CLENo
# MFGWIP  MWHMWH0VCRTYP+VCRNUMNo
# MFGWIP  MWHMWH1TRKTYP+STRDATYes
# MGTATCUD  ATCUDATCUD0CPY+CODNUM+SEQNo
# MGTWASTE  MGTWMGTW1CODNo
# MIGX  MIGXMIGX0MIGREFNUMNo
# MIGXTBLCMP  MIGXTCPMIGXTCP0MIGREFNUM+TMNBRNo
# MIGXTBLDIF  MIGXTDFMIGXTDF0MIGREFNUM+TMNBR+TDFNBRNo
# MIGXTBLMAP  MIGXTMMIGTM0MIGREFNUM+TMNBRNo
# MIGXTBLMAP  MIGXTMMIGTM1TMSTATCODYes
# MKGLEVEL  MKLMKL0OPGNUM+KEYTYPE+DATAKEYNo
# MKGOPG  MOGMOG0MKGQUR+OPGNUM+TGRNo
# MKGOPG  MOGMOG1MKGQUR+TGRYes
# MKGOPG  MOGMOG2OPGNUM+TGRYes
# MKGQUR  MQRMQR0QURNUMNo
# MKGQURPPL  MQPMQP0QURNUMYes
# MKGQURPPL  MQPMQP1QURNUM+PPLORDNo
# MMSDEFVAL  MMVMMV0ID+CODFIC+CODZONENo
# MMSPAR  MMSMMS0IDNo
# MODSCALE  MODLMOD1MODSCALENo
# MTCAUTO  MTUMTU0NUMNo
# MTCBATCH  MTBMTB0MTCNUM+ACCNUM+DUDLIGNo
# MTCGAUTMP  MGTMGT0COD+LINNUM+CLEA1+CLEA2+ACCNUMNo
# MTKCRDASW  MTAMTA0MFGTRKNUM+OPETRKLIN+QSTNUMNo
# MTOHEAD  MTOMTO0MTOREFNo
# MTOLINK  MLKMLK0STOFCY+ITMREF+DEMTYP+DEMNUM+DEMLIN+DEMSEQYes
# MTOLINK  MLKMLK1STOFCY+ITMREF+RESSTYP+RESSNUM+RESSLIN+RESSSEQYes
# MWMCRDASW  MWAMWA0MFGNUM+BOMOPE+ITMREF+IPTDAT+MVTSEQ+QSTNUMNo
# NCSADES  NCSADENCSADE0NCSID+CODBLBNo
# NCSAPPROVER  NCSAPPRNCSAPPR0NCSID+APPRLNNo
# NCSAPPROVER  NCSAPPRNCSAPPR1NCSID+NCSAPPUSRYes
# NCSAPPROVER  NCSAPPRNCSAPPR2NCSID+SORTSEQYes
# NCSBPC  NCSBPCNCSBPC0NCSID+ORIGCLNNo
# NCSBPC  NCSBPCNCSBPC1NCSID+BPCNUMNo
# NCSBPC  NCSBPCNCSBPC2NCSID+SORTSEQYes
# NCSBPS  NCSBPSNCSBPS0NCSID+ORIGSLNNo
# NCSBPS  NCSBPSNCSBPS1NCSID+BPSNUMNo
# NCSBPS  NCSBPSNCSBPS2NCSID+SORTSEQYes
# NCSDES  NCSDESNCSDES0NCSIDNo
# NCSDOCHDR  NCSDHDNCSDHD0NCSID+DOCLINNo
# NCSDOCHDR  NCSDHDNCSDHD1VCRNUM+VCRLINYes
# NCSDOCLIN  NCSDLNNCSDLN0NCSID+DOCLIN+SUBLINNo
# NCSDOCOPE  NCSDOPNCSDOP0NCSID+DOCLINNo
# NCSEXTUSR  NCSEUNCSEU0NCSID+ORIGELNNo
# NCSEXTUSR  NCSEUNCSEU1NCSID+EXTCONTACTNo
# NCSEXTUSR  NCSEUNCSEU2NCSID+SORTSEQYes
# NCSINTUSR  NCSIUNCSIU0NCSID+ORIGILNNo
# NCSINTUSR  NCSIUNCSIU1NCSID+USERNo
# NCSINTUSR  NCSIUNCSIU2NCSID+SORTSEQYes
# NCSRECENT  NCSRCNCSRC0NCSIDNo
# NCSREJDES  NCSREJNCSREJ0NCSIDNo
# NETAUTO  NTONTO0ACCNUM+DUDLIG+INDNo
# NETAUTO  NTONTO1UIDUSRYes
# NETAUTO  NTONTO2ACCNUMVCRYes
# NOTCATEG  NTGNTG0NTGTYP+NTGCODNo
# NOTE  NTSNTS0CODE+NTSCOD2No
# NPICOMPONENT  NPICNPIC0NPICOD+NPIREV+MFGFCY+BOMSEQ+CPNTYP+CPNREF+CPNREV+CPNFCYNo
# NPICOMPONENT  NPICNPIC1NPICOD+NPIREV+MFGFCYYes
# NPICOMPONENT  NPICNPIC2ISPARENT+CPNREFYes
# NPICOMPREF  NPICREFNPICR0NPICOD+NPIREV+MFGFCY+BOMSEQ+CPNTYP+CPNREF+CPNREV+CPNFCY+CPNREFSEQNo
# NPIHEADER  NPIHNPIH0NPICOD+NPIREV+MFGFCYNo
# NPIPWU  NPIWNPIW0NPICOD+NPIREV+MFGFCY+BOMSEQ+LEVELNo
# OMMRESULT  MREMRE0OPGNUM+MRENUMNo
# OMMRPT  OMROMR0LAN+MAGTPLNo
# OPERATIONS  OPSOPS0OPSNUMNo
# OPERATIONS  OPSOPS1MFGNUM+OPENUM+OPESPLNUMNo
# OPERATIONS  OPSOPS2POHNUM+POPLIN+POPSEQYes
# OPERATIONS  OPSOPS3MFGFCY+OPESTR+MFGNUMYes
# OPPOR  OPPOPP0OPPNUMNo
# OPPOR  OPPOPP2OPPCMGNUMYes
# OPPOR  OPPOPP3OPPOPGNUMYes
# OPPOR  OPPOPP4OPPCMPYes
# OPPOR  OPPOPP5OPPMCNYes
# OPPORCPP  OCPOCP0OPPNUM+CPPNo
# OPPORCRM  OPPCRMOPPCRM0OPPNUMNo
# OPPORI  OPPIOPPIAUUIDNo
# OPPORPJM  OPPPJMOPPPJM0OPPNUMNo
# OPPORPJM  OPPPJMOPPPJM1OPEDEFFCY+OPPNUMNo
# OPPORPJMI  OPJIOPPIUIDSES+GRPOPPNo
# OPPORSBB  OBBOBB0OPPNUM+SBBPJTNo
# OPPORSTA  OSAOSA0OPPNUM+STELINXNo
# OPPORSTA  OSAOSA1OPPNUM+STRDATX+STELINXNo
# OPPORSTB  OSBOSB0OPPNUM+STELINNo
# OPPORSTB  OSBOSB1OPPNUM+STRDAT+STELINNo
# ORDCOMP  DOODOO0BPRNUMNo
# ORDCOV  ORCORC0VCRTYPDST+VCRNUMDST+VCRLINDST+VCRSEQDST+WIPSTADSTYes
# ORDCOV  ORCORC1VCRTYP+VCRNUM+VCRLIN+VCRSEQYes
# ORDERS  ORDORD0WIPTYP+WIPNUM+ITMREFNo
# ORDERS  ORDORD1STOFCY+ITMREF+ENDDATYes
# ORDERS  ORDORD2ITMREF+ENDDATYes
# ORDERS  ORDORD3STOFCY+VCRTYP+VCRNUM+VCRLIN+VCRSEQYes
# ORDERS  ORDORD4ITMREF+STOFCY+WIPTYPYes
# ORDOOPAR  OROORO0IDNo
# ORDOPPAR  ORPORP0IDNo
# OVENAT  ONAONA0OVENATNo
# OVERHEAD  OVEOVE0OVECODNo
# PARADC  PDCPDC0STOFCYNo
# PARESC  PECPEC0ESCNUMNo
# PARESC  PECPEC1ENAFLG+ESCCATYes
# PAREVT  PVTPVT0EVT+PLN+EVTINTNo
# PAREVT  PVTPVT1EVT+EVTINTNo
# PAREVTD  PVDPVD0EVTINT+FLDNAMNo
# PAREVTD  PVDPVD1EVTINTYes
# PAREVTD  PVDPVD2EVTINT+NUMLIG+FLDNAMNo
# PARFLUX  PFLPFL0CODTXS+COA+POSTXSNo
# PARFLUXDET  PFDPFD0CODTXS+COA+POSTXS+GACNo
# PARFLUXDET  PFDPFD1CODTXS+COA+GACNo
# PARJAL  PJAPJA0MFGFCYNo
# PARLDAP  LDALDA0CPYNo
# PARMRP  PCBPCB0STOFCYNo
# PARMTO  PTOPTO0PTOCODNo
# PARSTA1  PS1PS10CODNo
# PARSTA2  PS2PS20CODNo
# PARSTA2  PS2PS21UPDCODYes
# PARSTALIG  PSLPSL0COD+NUMLIGNo
# PARSTOACC  PASPAS0LEG+CPY+TRSTYPNo
# PARTAXUSA  PTUPTU0CODNo
# PARTRZL  TZLTZL0KEYTZLNo
# PARTRZL  TZLTZL1OBJSRC+OBJDES+CPYNo
# PARTRZLDET  TZDTZD0KEYTZL+CODZONSRC+CODZONDESNo
# PARWIPACC  PWAPWA0LEG+CPY+TXNTYPNo
# PARWIPACCS  SWASWA0LEG+CPY+TXNTYPNo
# PAYACCNUM  PANPAN0TYPNUM+NUM+STA+ACCNUMNo
# PAYACCNUMD  PMDPMD0NUM+ACCSTA+ACCNUMNo
# PAYFRM  FRMFRM0FRMFLG+FRMNUMNo
# PAYFRM  FRMFRM1FRMFLG+TFBDAT-FILIDMODYes
# PAYFRM  FRMFRM2FRMFLG+FRMGRPYes
# PAYLOT  PYLPYL0CODNo
# PAYLOT  PYLPYL1STAYes
# PAYMENTA  PYAPYA0NUM+LIN+LINANANo
# PAYMENTD  PYDPYD0NUM+LINNo
# PAYMENTD  PYDPYD1DUDNUM+DUDLIG+NUM+LINNo
# PAYMENTD  PYDPYD2NUM+LIN+CURLINNo
# PAYMENTH  PYHPYH0NUMNo
# PAYMENTH  PYHPYH1FRMFLG+FRMNUM+FRMLINYes
# PAYMENTH  PYHPYH2PAYLOT+PAYLOTLIG+NUMNo
# PAYMENTH  PYHPYH3PAYTYP-NUMNo
# PAYMENTH  PYHPYH4DUDDAT+NUMNo
# PAYMENTH  PYHPYH5ACCDATYes
# PAYMENTPORD  PYPTDPYPTD0NUM+LINNo
# PAYMENTPORH  PYPTHPYPTH0NUMNo
# PAYMTCTMP  PMPPMP0NUM+NUMORD+LEDTYP+FCY+ACC+BPR+OCC1+OCC2Yes
# PAYMTCTMP  PMPPMP1NUM+NUMORD+LEDTYP+FCY+ACC+BPR+ACCNUMYes
# PAYMTCTMP  PMPPMP2NUM+NUMORD+LEDTYP+CUR+FCY+ACC+BPR+OCC1+OCC2Yes
# PAYMTCTMP  PMPPMP3UIDUSRYes
# PAYMTCTMP2  PM2PM20TYP+NUM+LEDTYP+CUR+FCY+ACC+BPR+ACCNUMNo
# PAYMTCTMP2  PM2PM21UIDUSRYes
# PAYORDER  PYOPYO0DUDNUM+DUDLIG+PAYNUMNo
# PAYTMP  PTPPTP0TYPREC+NUM+CODACE+LIGCODACE+VCRNUM+LIG+NUMORDNo
# PAYTMP  PTPPTP1TYPREC+NUM+CODACE+VCRNUM+LIG+LIGCODACE+NUMORDNo
# PAYTMP  PTPPTP2TYPREC+NUM+LIG+DUDNUM+DUDLIG+CODACE+LIGCODACEYes
# PAYTMP  PTPPTP3UIDUSRYes
# PAYVAT  PYHVPYHV0PAYNUM+PAYLIN+PAYMENTSTANo
# PBDBPGRP  PBDBPGPBDBPG0COD+LEGNo
# PBDBPGRPD  PBDBPDPBDBPD0COD+LEG+BPRNo
# PBDCONFIG  PBDCNFPBDCNF0CODE+LEGNo
# PBDCONFIG  PBDCNFPBDCNF1LEG+GRPORCPY+LEDTYP+ROOTACCYes
# PBDCONFIGD  PBDCNFDPBDCNFD0CODE+LEG+ISINCLUDED+LINENo
# PBDECOCOD  PBDECOPBDECO0COD+LEGNo
# PBDECOCOD  PBDECOPBDECO1LEG+CODNo
# PBDECODITM  PBDEITPBDEIT0LEG+ITMNo
# PBDGEN  PBDGENPBDGEN0CODENo
# PBDGEND  PBDGENDPBDGEND0CODE+LEG+ISDETAIL+ISOITEM+LINENo
# PBDUICONF  PBDUICPBDUIC0LEGNo
# PBDUICONFD  PBDUIDPBDUID0LEG+LINNo
# PDPDET  PDDCBD0STOFCY+ITMREF+BUC+REQDAT+WIPTYP+WIPNUMNo
# PDPDET  PDDCBD1STOFCY+SUGTYP+SUGSTA+SUGNUMYes
# PDPDET  PDDCBD2STOFCY+ITMREF+WIPTYP+WIPSTAYes
# PDPDET  PDDCBD3ITMREF+STOFCY+BUC+REQDAT+WIPTYP+WIPNUMNo
# PDPDET  PDDCBD4ITMREFORI+STOFCY+WIPTYP+WIPSTAYes
# PDPHEA  PDHCBH0STOFCY+ITMREFNo
# PDPHEA  PDHCBH1STOFCY+LLC+ITMREFNo
# PERIOD  PERPER0CPY+LEDTYP+FIYNUM+PERNUMNo
# PERIOD  PERPER1LEDTYPYes
# PFOOTINV  PFIPFI0PFINUMNo
# PHONECALL  CLLCLL0CLLNUMNo
# PHONECALL  CLLCLL1CLLDATXYes
# PHONECALL  CLLCLL2CLLCMPYes
# PHONECALL  CLLCLL3CLLCCNYes
# PHONECALL  CLLCLL4CLLREP+CLLDATXYes
# PHONECALL  CLLCLL5CLLCMGNUMYes
# PHONECALL  CLLCLL6CLLOPGTYP+CLLOPGNUMYes
# PHONECALL  CLLCLL7CLLORIADI+CLLORIVCR+CLLORIVCRLYes
# PHONECALL  CLLCLL8CLLDAT+CLLHOU+CLLNUMNo
# PHONING  OMPOMP0OMPNUMNo
# PHONING  OMPOMP1CMGNUMYes
# PHONING  OMPOMP2OMPSTRYes
# PHYBUI  BUIBUI0BUICODNo
# PHYELT  PHYPHY0PHYREFNo
# PHYELT  PHYPHY3BAC+CPYYes
# PHYELT  PHYPHY4CPY+FCY+PHYREFNo
# PHYELT  PHYPHY5AASREF+PHYREFNo
# PHYLCT  LCTLCT0LCTCODNo
# PHYLCT  LCTLCT1FCY+LCTCODNo
# PHYLCT  LCTLCT2BAC+FCY+LCTCODNo
# PHYMVT  PMVTPMVT0PHYREF+NUMNo
# PIMPL  PIMPIM0PIMNUMNo
# PIMPL  PIMPIM1OPPNUM+TASCODYes
# PIMPL  PIMPIM2OPPNUM+PBUCODYes
# PIMPL  PIMPIM4OPPNUMYes
# PIMPLSEL  PISPIS0PIMSSS+SEQYes
# PINVOICE  PIHPIH0NUMNo
# PINVOICE  PIHPIH1BPR+BPRVCRYes
# PINVOICE  PIHPIH2GTE+NUMNo
# PINVOICE  PIHPIH3ACCDAT+BPRYes
# PINVOICE  PIHPIH4CUR+BPR+NUMNo
# PINVOICE  PIHPIH5CPY+EECNUMDEB+ACCDATYes
# PINVOICE  PIHPIH6RCRNUM+RCRDATYes
# PINVOICED  PIDPID0NUM+PIDLINNo
# PINVOICED  PIDPID1TYPORI+NUMORI+LINORI+SEQORI+NUM+PIDLINNo
# PINVOICED  PIDPID2ITMREF+NUM+PIDLINNo
# PINVOICED  PIDPID3BPR+INVTYP+ITMREF+NUM+PIDLINNo
# PINVOICED  PIDPID4POHNUM+POPLIN+POQSEQYes
# PINVOICED  PIDPJMPJT1PJTYes
# PINVOICEV  PIVPIV0NUMNo
# PITCOUNT  PCTPCT0SRENUM+TPYFLG+FGVCAH+BPC+MAC+PBL+HDT+HDTSEQNo
# PITCOUNT  PCTPCT1CONNUMYes
# PITCOUNT  PCTPCT2LOONo
# PITDEB  PDBPDB0BPR+ITMREF+PBLNo
# PITDEBD  PBDPBD0BPR+ITMREF+PBL+PBDLINNo
# PIVOTS  PITPIT0IDNo
# PIVZON  PIZPIZ0ID+LINNo
# PIVZON  PIZPIZ1ID+CODFIC+CODZONENo
# PIWRK  PKWSKW0PRONUM+LEVNo
# PIWRK  PKWSKW1CREUSR+CREDAT+PRONUM+LEVNo
# PJMAFF  PAFPAF0OPPNUM+PAFCLBNo
# PJMAUS  PAUSPAUSPAUSNo
# PJMAUSCAVA  PJCVPJCV0PAUS+PAUSSEQNo
# PJMBUD  PJBUPJBU0OPPNUM+PBUCODNo
# PJMBUD  PJBUPJBU1OPPNUM+PBUSOR+PBUCODNo
# PJMBUD  PJBUPJBU2OPPNUM+PBUPAEYes
# PJMBUDI  PJBUIPJBUIUIDSES+GRPOPP+GRPPBUNo
# PJMBUDLIG  PJLBPJLB0OPPNUM+PBUCOD+PLBSEQNo
# PJMBUDLIGI  PJLBIPJLBIUIDSES+GRPOPP+GRPPBU+IMPSEQNo
# PJMBUDTRQ  PJQPTQ0PBTGRP+PBTCODNo
# PJMBUDTRS  PJSPTS0PBTGRP+PBTCODNo
# PJMCLOB  PJCBPJCB0CODBLB+IDENT1+IDENT2+IDENT3+IDENT4No
# PJMCNSVTETM1  VT1VT10PRCIDN+VTESEQ+VT1SEQYes
# PJMCNSVTETM2  VT2VT20PRCIDN+VT2SEQNo
# PJMCNSVTETM2  VT2VT21PRCIDN+OPPNUM+TASCOD+OPENUM+OPESPLNUM+POANUM+DATBEGPERNo
# PJMCNSVTETMP  VTEVTE0PRCIDN+VTESEQNo
# PJMCNSVTETMP  VTEVTE1PRCIDN+PAUS+DATBEGPERNo
# PJMCNSVTETMP  VTEVTE2PRCIDN+PAUSYes
# PJMCOSTCTR  PJCCPCC0PCCCODNo
# PJMCOSTDAT  PCDCSTD0PCCCOD+PCCDATCSTNo
# PJMCOSTGRP  PJCGPCG0PCCCOD+PCGTYP+PCGGRPMAT+PCGGRPLAB+PCGGRPMACNo
# PJMDE  PJEPJE0PDESSS+PDESEQNo
# PJMFINCTORPT  PJMCTOPJC0KEYEXT+SHOWGRP+OPPNUM+PSCSEQNo
# PJMFINCTORPT  PJMCTOPJC1KEYEXT+SHOWGRP+OPPNUM+PBUPAE+PBUCOD+PCCGRPSOR+PCCGRP+PCCCODYes
# PJMFINOVRRPT  PJMRPTPJMR0KEYEXT+SHOWGRP+OPPNUM+PSCSEQNo
# PJMFINOVRRPT  PJMRPTPJMR1KEYEXT+SHOWGRP+OPPNUM+PBUPAE+PBUCODYes
# PJMFINOVRRPT  PJMRPTPJRM2KEYEXT+SHOWGRP+OPPNUM+PBUPAE+PBUSOR+PBUCODYes
# PJMFINOVRRPT  PJMRPTPJRM3KEYEXT+SHOWGRP+OPPNUM+PBUCODYes
# PJMMSTNEXINV  PJMSTPJMST0OPPNUM+TASCOD+PBUCOD+SEQLINNo
# PJMMSTNEXINV  PJMSTPJMTS1OPPNUM+PBUCOD+TASCOD+SEQLINNo
# PJMOPEAFF  PJOAPJOA0OPPNUM+TASCOD+OPENUM+OPESPLNUM+POANUMNo
# PJMOPEAFF  PJOAPJOA2POACLBYes
# PJMOPEAFFI  PJOAIPJOAIUIDSES+GRPOPP+GRPTAS+IMPSEQ+IMPSEQ1No
# PJMOPSNPD  PJSNPDPJSNPD0SNPCOD+SNPSEQNo
# PJMOPSNPH  PJSNPHPJSNPH0SNPCODNo
# PJMPRGBILD  PBILDPBILD0PRGBILNUM+SEQLINNo
# PJMPRGBILD  PBILDPBILD1PRGBILNUM+PERSTRDAT+SEQLINNo
# PJMPRGBILH  PBILHPBILH0PRGBILNUMNo
# PJMPRGBILH  PBILHPBILH1SOHNUM+SOPLIN+SOPSEQNo
# PJMPRGBILH  PBILHPBILH2PRJLNKYes
# PJMSALITMD  PSPLDPSPLD0OPPNUM+PBUCOD+TASCOD+SEQNUMNo
# PJMSALITMD  PSPLDPSPLD1OPPNUM+TASCOD+PBUCOD+SEQNUMNo
# PJMSC  PJCPJC0PSCSSS+PSCSEQNo
# PJMSC  PJCPJC1PSCSSS+OPPNUM+PBUPAE+PBUCODYes
# PJMSC  PJCPJC2PSCSSS+OPPNUM+PBUPAE+PBUSOR+PBUCODYes
# PJMSCCT  PJCCTPJC0PSCSSS+PSCSEQNo
# PJMSCCT  PJCCTPJC1PSCSSS+OPPNUM+PBUPAE+PBUCOD+PCCGRPSOR+PCCGRP+PCCCODYes
# PJMSNPD  PSNPDPSNPD0KEYEXTNo
# PJMSNPD  PSNPDPSNPD1SNPCOD+SNPSEQNo
# PJMSNPH  PSNPHPSNPH0SNPCODNo
# PJMSNPW0  PSW0PSW0PRONUM+OPPNUM+PBUPAE+PBUCODNo
# PJMSNPW0  PSW0PSW1PRONUM+OPPNUM+PBUPAE+PBUSOR+PBUCODNo
# PJMSNPW1  PSW1PSW1PRONUM+OPPNUM+PBUPAE+PBUCOD+PCCGRPSOR+PCCGRP+PCCCODNo
# PJMSOLITMD  PSODPSOD0PSONUM+SEQNUMNo
# PJMSOLITMD  PSODPSOD1PSONUM+OPPNUMYes
# PJMSOLITMH  PSOHPSOH0PSONUMNo
# PJMSOLITMH  PSOHPSOH1DOCTYP+HDOCNUMYes
# PJMSOLITMH  PSOHPSOH2OPPNUMYes
# PJMSOLITMO  PSOOPSOO0PSONUM+OPPNUM+PBUCOD+TASCOD+SEQNUMNo
# PJMTIMACT  PTEATPTEAT0CLB+PTESEQNo
# PJMTIMACT  PTEATPTEAT1CLB-PTEDAT+OPPNUM+PTETYP+PTESEQNo
# PJMTIMACTI  PTEATIPTEATI0AUUIDNo
# PJMTIMCAT  PJTCPJTC0CATCODNo
# PJMTIMEMP  PTEPTE0CLB+PTESEQNo
# PJMTIMEMP  PTEPTE1PIMTASCODYes
# PJMTIMEMP  PTEPTE2PIMPBUCODYes
# PJMTIMEMP  PTEPTE3CLB-PTEDAT+OPPNUM+PTESEQNo
# PJMTIMEMPI  PTIPTE0AUUIDNo
# PJMTIMEMPRPT  PTERPTER0RPTCODNo
# PJMTIMEMPTMP  PTETPTET0IDENT1+CLB+PTESEQNo
# PJMTIMEMPTMP  PTETPTET1IDENT1+CPY+CUR+FCY+PCCCODYes
# PJMTIMEMPTMP  PTETPTET2IDENT1+CPY+CUR+FCY+PCCCOD+OPPNUMYes
# PJMTIMEMPTMP  PTETPTET3IDENT1+CPY+CUR+FCY+PCCCOD+PTEDATYes
# PJMTIMEMPTMP  PTETPTET4IDENT1+CPY+CUR+FCY+PCCCOD+OPPNUM+SEP+PTEDATYes
# PJMTSK  PJTAPTA0OPPNUM+TASCODNo
# PJMTSK  PJTAPTA1KEYCONCATNo
# PJMTSK  PJTAPTA2OPPNUM+TASSOR+TASCODNo
# PJMTSK  PJTAPTA3OPPNUM+TASPAEYes
# PJMTSKCAT  PTCCTA0TCACODNo
# PJMTSKCATOPE  PTCOPCTO0TCACOD+IPTCOSEQNo
# PJMTSKDEP  PKDPKD0OPPNUM+TASCOD+OPENUM+ITTSEQNo
# PJMTSKDEP  PKDPKD1OPPNUM+TASCOD+OPENUMYes
# PJMTSKDEP  PKDPKD2OPPNUM+TASCOD+ITTSEQYes
# PJMTSKDEP  PKDPKD3OPPNUM+TASCODYes
# PJMTSKI  PJTAIPJTAIUIDSES+GRPOPP+GRPTASNo
# PJMTSKITM  JTTJTT0OPPNUM+TASCOD+ITTSEQNo
# PJMTSKITM  JTTJTT1OPPNUM+TASCOD+ITMREFYes
# PJMTSKITMI  JTTIJTTIUIDSES+GRPOPP+GRPTAS+IMPSEQNo
# PJMTSKLNK  PTLNKPTLNK0OPPNUM+TASCOD+SEQNUMNo
# PJMTSKOPE  PTKOPTKO0OPPNUM+TASCOD+OPENUM+OPESPLNUMNo
# PJMTSKOPEI  PTKOIPTKOIUIDSES+GRPOPP+GRPTAS+IMPSEQNo
# PJMTSKOPELNK  OPLNKOPLNK0OPPNUM+TASCOD+OPENUM+OPESPLNUM+SEQNUMNo
# PLANACT  PLAACTPLAACT0ACTIONIDNo
# PLANACT  PLAACTPLAACT1TRANTYPE+TRANACTIONNo
# PLANDET  PLADETPLADET_0PLANID+LINENONo
# PLANDET  PLADETPLADET_1PLANID+SORTSEQYes
# PLANHDR  PLAHDRPLAHDR_0PLANIDNo
# PLGMKG  PLGPLG0CMGNUMYes
# PLGMKG  PLGPLG1CLSNUMYes
# PLGMKG  PLGPLG2CLSNUM+SSSYes
# PLGOPG  PLOPLO0OPGNUMYes
# PLGOPG  PLOPLO1CLSNUMYes
# PLGOPG  PLOPLO2CMGNUM+OPGNUM+SSSYes
# PLMDEFVAL  PDVPDV0ID+CODFIC+CODZONENo
# PLMPAR  PPAPPA0IDNo
# POOL  POOPOO0POO+LINNo
# POPSCALEXP  CEPCEP0WSTFCY+WST+STRDAT+ENDDATNo
# POPSCUSFLDS  PSCFPSCF0MENNUM+MESNUMNo
# POPSCUSVALS  PSCVPSCV0FCYNo
# POPSMRK  MRKMRK0MFGNUM+OPENUM+MRKIDNo
# POPSOBJ  PSOBJPSOBJ0FCY+TYP+IDENT1+IDENT2No
# POPSPIN  PINPIN0MFGNUM+OPENUM+OPESPLNUMNo
# POPSTAG  TAGTAG0TAGIDNo
# PORDER  POHPOH0POHNUMNo
# PORDER  POHPOH1BPSNUM+ORDDAT+POHNUMNo
# PORDER  POHPOH2ORDDAT+POHNUMNo
# PORDERC  POCPOC0POHNUM+POPLINNo
# PORDERC  POCPOC1POHNUM+ITMREF+PRHFCYNo
# PORDERC  POCPOC2ITMREF+BETFCY+STRDATYes
# PORDERP  POPPOP0POHNUM+POPLIN+POPSEQNo
# PORDERP  POPPOP1POHNUM+POPLIN+POPDATNo
# PORDERP  POPPOP2PRHFCY+POHNUM+POPLINYes
# PORDERP  POPPOP3ITMREF+POHTYPYes
# PORDERP  POPPJMPJT1PJTYes
# PORDERQ  POQPOQ0POHNUM+POPLIN+POQSEQNo
# PORDERQ  POQPOQ1LININVFLG+WIPSTA+BPSINV+ITMREF+POHNUMYes
# PORDERQ  POQPOQ2LINCLEFLG+WIPSTA+PRHFCY+BPSNUM+POHNUMYes
# PORDERQ  POQPOQ3POHNUM+POQLNKNo
# PORDERQ  POQPOQ4VCRTYPORI+VCRNUMORI+VCRLINORI+VCRSEQORI+ITMREFORIYes
# PORDITM  POIPOI0USR+NOLIGNo
# PORDITM  POIPOI1USR+POILINNo
# PORQRC  PORQRCPORQRC0DOCTYP+DOCNUMNo
# POSCOD  POSPOS0CRY+POSCOD+POSCTY+POSCTYCODNo
# POSCOD  POSPOS1CRY+POSCTY+POSCODYes
# POSCOD  POSPOS2CRY+POSCTYSEA+POSCODYes
# PPREASON  PPRPPR0PRIRENNo
# PPRICCONF  PPCPPC0PLINo
# PPRICCONF  PPCPPC1PLIENAFLG+PLITYP+PIO+PLINo
# PPRICFICH  PPFPPF0PLI+PLICRDNo
# PPRICLINK  PPKPPK0CLENo
# PPRICLIST  PPLPPL0PLI+PLICRD+PLILINNo
# PPRICLIST  PPLPPL1PLI+PLICRI+PLISTRDATYes
# PPRICLIST  PPLPPL2PLI+PLICRI1+PLISTRDATYes
# PPRICLIST  PPLPPL3PLI+PLICRI2+PLISTRDATYes
# PPRIVARWRK  PPVPPVPIDYes
# PQUOTAT  PQHPQH0PQHNUMNo
# PQUOTAT  PQHPQH1PQHDAT+PQHNUMNo
# PQUOTATD  PQDPQD0PQHNUM+PQDLINNo
# PQUOTATD  PQDPQD1PQHNUM+ITMREFYes
# PQUOTATF  PQFPQF0PQHNUM+BPSNUMNo
# PQUOTATF  PQFPQF1BPSNUM+PQHNUMNo
# PRECEIPT  PTHPTH0PTHNUMNo
# PRECEIPT  PTHPTH1BPSNDEYes
# PRECEIPT  PTHPTH2BPSNUM+RCPDATYes
# PRECEIPT  PTHPTH3RCPDAT+PTHNUMNo
# PRECEIPT  PTHPTH4CPY+EECNUMDEB+RCPDATYes
# PRECEIPTD  PTDPTD0PTHNUM+PTDLINNo
# PRECEIPTD  PTDPTD1LININVFLG+BPSINV+ITMREF+PTHNUM+PTDLINNo
# PRECEIPTD  PTDPTD2POHNUM+POPLIN+POQSEQ+PTHNUM+PTDLINNo
# PRECEIPTD  PTDPTD3PRHFCY+BPSNUM+ITMREF+PTHNUM+PTDLINNo
# PRECEIPTD  PTDPJMPJT1PJTYes
# PREPINVOICE  PREPIPREPI0PCNTNUMNo
# PREPINVOICED  PREPIDPREPID0PCNTNUM+PCNTLINNo
# PREPINVOICED  PREPIDPREPID1INVNUMYes
# PREPINVOICEF  PREPIDFPREPIDF0PCNTNUMF+PCNTLINFYes
# PREPINVOICEF  PREPIDFPREPIDF1INVNUMFYes
# PREPINVOICEF  PREPIDFPREPIDF2PCNTNUMF+INVNUMF+PCNTLINFNo
# PREPINVOICEP  PREPIPPREPIP0INVNUM+PAYNUM+PAYLINNo
# PREPINVOICEP  PREPIPPREPIP1PAYNUMYes
# PREQUIS  PSHPSH0PSHNUMNo
# PREQUIS  PSHPSH1PSHFCY+PSHNUMNo
# PREQUIS  PSHPSH2PRQDAT+PSHNUMNo
# PREQUIS  PSHPSH3PSHNUMMMS+PSHNUMNo
# PREQUISA  PSAPSA0PSHNUM+PSDLIN+PQHNUM+PQDLINNo
# PREQUISA  PSAPSA1PQHNUM+PQDLIN+PSHNUM+PSDLINNo
# PREQUISD  PSDPSD0PSHNUM+PSDLINNo
# PREQUISD  PSDPSD1LINORDFLG+ITMREF+EXTRCPDAT+PSHNUM+PSDLINYes
# PREQUISD  PSDPSD2LINORDFLG+LINBUY+EXTORDDATYes
# PREQUISD  PSDPSD3PSDNUMMMS+PSHNUM+PSDLINNo
# PREQUISD  PSDPJMPJT1PJTYes
# PREQUISO  PSOPSO0PSHNUM+PSDLIN+POHNUM+POPLIN+POQSEQNo
# PREQUISO  PSOPSO1POHNUM+POPLIN+POQSEQ+PSHNUM+PSDLINNo
# PREREPORT  PPPPPP0NUM+TYPOBJ+CURNo
# PRESP  PPHPPH0BPSNUM+PQHNUM+PQDLINNo
# PRESP  PPHPPH1ITMREF+BPSNUM+PQHNUMYes
# PRESP  PPHPPH2BPSNUM+ITMREF+PQHNUMYes
# PRESPD  PPDPPD0BPSNUM+PQHNUM+PQDLIN+PPDLINNo
# PRESPD  PPDPPD1BPSNUM+PQHNUM+ITMREF+PPDLINYes
# PRESTCOV  PCOPCO0CONNUM+TPL+MACNUM+TYPSVCYes
# PRETURN  PNHPNH0PNHNUMNo
# PRETURN  PNHPNH1BPSNUM+RTNDATYes
# PRETURN  PNHPNH2RTNDAT+PNHNUMNo
# PRETURN  PNHPNH3CPY+EECNUMDEB+RTNDATYes
# PRETURND  PNDPND0PNHNUM+PNDLINNo
# PRETURND  PNDPND1PTHNUM+PTDLINYes
# PRETURND  PNDPND2LININVFLG+BPSINV+ITMREF+PNHNUM+PNDLINNo
# PRETURND  PNDPND3POHNUM+POPLIN+POQSEQYes
# PRETURND  PNDPJMPJT1PJTYes
# PRICSTRUCT  PRSPRS0BPCBPS+PLISTCNo
# PRJFAS  PJFPJF0PRJ+LIGNo
# PRJLOT  PJLPJL0PRJ+LOTNo
# PRMDADSU  PRMPRM0CPYNo
# PROJET  PRJPRJ0PRJNo
# PROPLN  PLPPPL0PROPLN+FIYENDDAT+PERENDDATNo
# PROPLNH  PLHPPH0PROPLNNo
# PROPLNH  PLHPPH1CPY+PROPLNNo
# PROPLNH  PLHPPH2CPY+FCY+PROPLNNo
# PROPLNH  PLHPPH3CPY+CNXYes
# PROROG  PROPRO0NUMYes
# PROROGPCE  PRPPRP0ACCNUMNo
# PROROGPCE  PRPPRP1NUM+ACCNUMNo
# PRTSCRWRK  PSWPSW0CREUSR+PRONUM+PRONUMSEQ+RECCOD+RECSEQNo
# PSEPLN  PSEPSE0CPY+PSEPLNNo
# PTDSTKVAL  PSVPSV0NUM+PIDLIN+PTHNUM+PTDLINNo
# PTDSTKVAL  PSVPSV1VALDATTIM+POHNUM+POPLIN+POQSEQ+TIAFLG+TYP+AUUIDNo
# PURTRS  PTRPTR0PTRTYP+PTRNUMNo
# PURTRS  PTRPTR1PTRNUM+PTRTYPNo
# PVCRFOOT  PVFPVF0VCRNUM+VCRTYP+INDNo
# PVCRFOOT  PVFPVF1VCRTYP+VCRNUM+INDNo
# PVCRFOOT  PVFPVF2NUM+VCRTYP+VCRNUM+INDNo
# PVCRVAT  PVVPVV0VCRNUM+VCRTYP+INDNo
# PVCRVAT  PVVPVV1VCRTYP+VCRNUM+INDNo
# PVCRVAT  PVVPVV2NUM+VCRTYP+VCRNUM+INDNo
# PWRKORDERS  PWOPWO0PRONUM+CODFNC+LINNUM+WIPTYP+WIPNUM+PSDLINNo
# PWRKPND  PWRPWR0PRONUM+PNHNUM+PNDLINNo
# PWRKPNH  PWEPWE0PRONUM+PNHNUMNo
# PWRKPNH  PWEPWE1PRONUM+CPY+PNHFCY+BPSINV+CUR+PNHNUMNo
# PWRKPOC  PWCPWC0PRONUM+POHNUM+POPLINNo
# PWRKPOP  PWPPWP0PRONUM+POHNUM+POPLIN+POPSEQNo
# PWRKPOQ  PWQPWQ0TYPORI+POHNUM+POPLIN+POQSEQNo
# PWRKPQF  PWFPWF0PRONUM+BPSNUMNo
# PWRKPTD  PWDPWD0PRONUM+PTHNUM+PTDLINNo
# PWRKPTH  PWHPWH0PRONUM+PTHNUMNo
# PWRKPTH  PWHPWH1PRONUM+CPY+PRHFCY+BPSINV+CUR+PTHNUMNo
# PWRKSTT  PWSPWS0PRONUM+CODFNC+VCRTYP+VCRNUM+VCRLIN+VCRSEQ+TRSTYPNo
# PYHCAS  PCHPCH1REGNUM+ACCNUM+REGLINYes
# PYHCAS  PCHPCH2NUMPCHYes
# PYHCAS  PCHPCH3REGNUM+RVSACCNUM+REGLINYes
# PYRAPAR  PYRAPYRA0IDNo
# QLYCRD  QLCQLC0QLYCRD+NUMLINNo
# QLYCRD  QLCQLC1QLYCRDDES+NUMLINYes
# QLYCRD  QLCQLC2SEQ+QLYCRD+NUMLINNo
# QLYCRDASW  QLAQLA0QLYCTLDEM+VCRLIN+CRDSEQ+QSTNUMNo
# QLYCRDNQA  NQANQA0COD+NQA+CODSMPNo
# QLYCRDQST  QLQQLQ0QSTNUMNo
# QLYWRK  QLWQLW0PRONUM+LINNUM+QSTNUMNo
# QUEUE  QUEQUE0NUMNo
# QURCRI  QCRQCR0QURNUM+PPLORDYes
# QURCRI  QCRQCR1QURNUM+PPLORD+CRINUMNo
# QURCRI  QCRQCR2QURNUM+CRICNDYes
# QURCRIVAL  QCVQCV0QURNUM+PPLORD+CRINUMYes
# QURCRIVAL  QCVQCV1QURNUM+PPLORD+CRINUM+CRIVALNUMNo
# QUREXTRACT  QTXQTX0QURNUMYes
# QURTMP  QTPQTP0QURNUM+PPLORD+CRINUM+KEYTGRYes
# QURTMP  QTPQTP1QURNUM+PPLORD+KEYTGRYes
# QURTMP  QTPQTP2KEYTGRYes
# QURTMP  QTPQTP3QURNUM+PPLORD+CRINUM+WKGTAB+KEYRECYes
# RBKBELDET  RBDRBD0RBKNUM+RBKLINNo
# RBKBELDET  RBDRBD1FRMNUMYes
# RBKBELDUD  RBURBU0RBKNUM+RBKLIN+LINNo
# RBKBELDUD  RBURBU1DUDNUM+DUDLIGYes
# RBKBELHEA  RBHRBH0RBKNUMNo
# RBKBELHEA  RBHRBH1ACCNUMNo
# RBKBELTMP  RBWRBW0RBKNUM+RBKLIN+LINNo
# RBKBELTMP  RBWRBW1DUDNUM+DUDLIGYes
# RBKRUBBEL  RRBRRB0RUBNo
# RCRINVOICE  RCHRCH0RCRNUMNo
# RCRINVOICE  RCHRCH1RCRTYP+NUMYes
# REACHPAR  RPARPA0IDNo
# RELBANK  RBKRBK0BAN+RBKNUM+RECTYP+RBKLINNo
# RELBANK  RBKRBK1BAN+RECTYP+OPEDAT+RBKNUM+RBKLINNo
# RELBANK  RBKRBK2BAN+RBKNUMYes
# RELBANK  RBKRBK3BAN+NUMRBKNo
# RELBANK  RBKRBK4NUMRBKNo
# RELBANKREM  RBRCRR0BAN+RBKNUM+RBKLIN+REMNUMNo
# RELMT940  RLTRLT0FILNUM+TRFNUM+SEQNUMNo
# RELMT940  RLTRLT1BAN+FILNUMYes
# RELMT940  RLTRLT2BAN+FILNUM+TRFNUM+SEQNUMNo
# RELMT940  RLTRLT3BAN+TRFNUM+SEQNUMYes
# RELMT940D  RLDRLD0FILNUM+TRFNUM+SEQNUM+LINNo
# RELMT940D  RLDRLD1BAN+FILNUMYes
# REPLINDEF  RLIRLI0LEG+RECTYP+CODNo
# REPLINDEF  RLIRLI1LEG+RECTYPYes
# REPLINDEF  RLIRLI2CODYes
# REPSEC  RSERSE0BPCNUM+REPNUMNo
# REPSEC  RSERSE1BPCNUMYes
# RESOURCES  RSSRSS0NUMNo
# RESRES  RRSRRS0NUMNo
# RESRES  RRSRRS1RRSORI+RRSORIVCRYes
# REVREC  REVRECREVREC0CPY+RRCCNo
# REVRECD  RRCDRRCC0RRCC+CPY+NUMCOLNo
# REVRECT  RRCTRRCT0RRVCOD+NUMCOL+RRTLINNo
# REVRECV  REVRECVREVRECV0RRVCODNo
# REVRECV  REVRECVREVRECV1RRCC+CPY+OPPNUM+INIDATNo
# REVRECVD  RRCVDRCCD0RRVCOD+NUMCOLNo
# RHSBONFAC  RHSBFRHSBFCT0NUMNo
# RITENZIONE  RTZRTZ0RITCODNo
# RITHIS  RTHRTH0PAYNUM+PIHNUM+RITCODNo
# RITMVT  RTMRTM0BPR+RITCOD+CPY+ANNNo
# RLSBONFAC  RLSBFRLSBFCT0NUM+SIDLINNo
# RLSBONFACI  RLSBFIRLSBFI0VCRTYP+VCRNUM+VATNo
# RLSBONFACI  RLSBFIRLSBFI1VCRTYP+VCRNUM+VATTYP+VATNo
# RLSBONFACI  RLSBFIRLSBFI2NUM+VCRTYP+VCRNUM+VATNo
# RLSBONFACO  RLSBFORLSBFO0TYP+NUM+LIG+DUDLIGNo
# RLSBONFACO  RLSBFORLSBFO1ACCNUM+DUDLIGNo
# RLSBONFACO  RLSBFORLSBFO2SOINUM+ACCNUM+DUDLIGNo
# RLSBONFACO  RLSBFORLSBFO3FLGCLE+FCY+BPRPAY+DUDDATYes
# RLSBONFACO  RLSBFORLSBFO4BPR+SOINUM+ACCNUM+DUDLIGNo
# RLSBONFACO  RLSBFORLSBFO5BPRPAY+SOINUM+ACCNUM+DUDLIGNo
# RLSBONFACO  RLSBFORLSBFO6FLGCLE+ACCNUM+DUDLIGNo
# RLSBONFACO  RLSBFORLSBFO7BPRPAY+BPR+NUMDUDNo
# RLSBONFACO  RLSBFORLSBFO8NUMDUDNo
# RLSBONFACO  RLSBFORLSBFO9BPR+BPAPAY+NUMDUDNo
# RNWPREP  RWPRWP0CPY+FCY+RNWAASREF+MOTHAASREFNo
# RNWPREP  RWPRWP1CPY+MOTHAASREFNo
# RNWPREP  RWPRWP2CPY+FCY+CCNREF+RNWAASREFYes
# RNWPREP  RWPRWP3RNWDONFLGYes
# ROUOPE  ROOROO0FCY+ITMREF+ROUALT+OPENUM+RPLINDNo
# ROUOPE  ROOROO1FCY+VALENDDATYes
# ROUOPE  ROOROO2FCY+WSTYes
# ROUOPE  ROOROO3FCY+LABWSTYes
# ROUOPE  ROOROO4FCY+STDOPENUMYes
# ROUOPESTD  ROTROT0STDOPENUM+FCYNo
# ROUOPESTD  ROTROT1FCY+STDOPENUMNo
# ROUSCD  ROSROS0FCY+ITMREF+ROUALT+OPENUMNo
# ROUSCD  ROSROS1FCY+ITMREF+ROUALT+NEXOPENUMYes
# ROUTING  ROHROH0ITMREF+ROUALT+FCYNo
# ROUTING  ROHROH1FCY+ITMREF+ROUALTNo
# RPLWST  RPWRPW0WST+WCRFCYNo
# RPTDS  RDSRDS0CRYCOD+LANNo
# RSLINESGER1  RSLG1RSLG1USERIDYes
# RSLINESGER1  RSLG1RSLG2USERID+GEREECNUM+TRNTYPNo
# RSLINESGER2  RSLG2RSLG2USERIDYes
# RSLINESGER2  RSLG2RSLG3USERID+GEREECNUM+TRNTYPYes
# RUBASSDEF  RDERDE0REFOBJ+DETAAS+ACM+CPYNo
# RUBASSDEF  RDERDE1NUMASSNo
# RUBASSDEFP  RDPRDP0REFOBJ+DETAAS+ACM+CPY+DPRPLNNo
# RUBASSDEFP  RDPRDP1NUMASS+DPRPLNNo
# RUBASSVAL  RVARVA1REFOBJ+DETAAS+ACM+CPY+VALDETAASNo
# RUBASSVAL  RVARVA0NUMASS+VALDETAASNo
# RUBASSVAL  RVARVA2REFOBJ+DETAAS+ACM+CPYYes
# RUBASSVALP  RVPRVP0NUMASS+VALDETAAS+DPRPLNNo
# RUBASSVALP  RVPRVP1REFOBJ+DETAAS+ACM+CPY+VALDETAAS+DPRPLNNo
# RVACOED  CODCOD0RVACOEREF+CLETABNo
# RVACOED  CODCOD1RVANAT+YEA+MONYes
# RVACOEH  COHCOH0RVACOEREFNo
# RVACOEH  COHCOH1CPY+RVACOEREFNo
# RVACOEH  COHCOH2RVACOEREF+CRITDAT+CRITNATNo
# RVMVAL  RVVRVV1ITMREF+FCY+ECCVALMAJ+ECCVALMINNo
# RVMVAL  RVVRVV0ITMREF+FCY+ECCSEQNo
# SAFTPTTMP1  SAFTPSAFTP0COD+EECNUMNo
# SAITRS  SAIHST0REFOBJ+TRSCODNo
# SAITRSDET  DSTDST0REFOBJ+TRSCOD+NUMMSK+CODMSK+CODZONNo
# SAITRSDET  DSTDST1REFOBJ+TRSCOD+CODMSKYes
# SAITRSDET  DSTDST2CODMSKYes
# SAITRSDET  DSTDST3BROMSKYes
# SAITRSDET  DSTDST4NUMMSKYes
# SALESREP  REPREP0REPNUMNo
# SALESREP  REPREP1AUSNUMYes
# SALESTAX  STBSTB0PID+VATYes
# SALESTAX  STBSTB1VCRNUM+VCRTYP+VAT+PIDYes
# SALTRS  SLTSLT0STRTYP+STRNUMNo
# SALTRS  SLTSLT1STRNUM+STRTYPNo
# SBGEO  SBGSBG0BPRNUMYes
# SBGEO  SBGSBG1CRY+ARACODYes
# SBGEO  SBGSBG2BPRNUM+CRY+ARACODNo
# SBODLINK  SBKSPK0CLENo
# SBPBL  SBPSBP0BPRNUMYes
# SBPBL  SBPSBP1PBLYes
# SBPBL  SBPSBP2BPRNUM+PBLNo
# SCALES  SLESLE0SLE+FCYNo
# SCALES  SLESLE1FCY+SLENo
# SCHEDULING  SCHSCH0MFGNUM+OPENUM+OPESPLNUMNo
# SCHGD  SGDSGD0VCRNUM+VCRLINNo
# SCHGH  SGHSGH0VCRNUMNo
# SCHGH  SGHSGH1SIHNUM+VCRNUMNo
# SCMAPAR  SZPSZP0IDNo
# SCMDPAR  SDPSDP0IDNo
# SCOHEAD  SCOSCO0SCONUMNo
# SCOHEAD  SCOSCO1MFGFCY+SCOTRKFLGYes
# SCOHEAD  SCOSCO2MTOREFYes
# SCOITM  SCISCI0SCONUM+SCILINNo
# SCOITM  SCISCI1VCRTYPORI+VCRNUMORI+VCRLINORI+VCRSEQORIYes
# SCOITM  SCISCI2POHNUM+POPLIN+POQSEQYes
# SCOITM  SCISCI3PJTYes
# SCOMAT  SCMSCM0SCONUM+SCILIN+SCMLINNo
# SCOMAT  SCMSCM1STOFCY+DLVDATYes
# SCOMAT  SCMSCM2STOFCY+PIO+DLVDATYes
# SCOMAT  SCMSCM3ITMREF+BOMALT+BOMSEQ+CPNITMREFYes
# SCOMAT  SCMSCM4POHNUM+POPLIN+POQSEQYes
# SCOSRV  SCSSCS0SCONUM+SCILIN+SCSLINNo
# SCOSRV  SCSSCS1POHNUM+POPLIN+POQSEQYes
# SCOSRV  SCSSCS2ITMREF+BOMALT+BOMSEQ+SRVITMREFYes
# SCOTRK  SCKSCK0SCONUM+SCILIN+SCSLIN+SCMLIN+PTHNUM+PTDLINNo
# SCOTRK  SCKSCK1PTHNUM+PTDLIN+SCONUM+SCILIN+SCSLIN+SCMLINNo
# SCOTRK  SCKSCK2POHNUM+POPLIN+POQSEQYes
# SCPASW  SCASCA0CLL+SCP+QSTNo
# SCPQST  SCQSCQ0SCPNUM+QSTNUMNo
# SCPQSTCND  SQCSQC0SCPNUM+QSTNUM+CNDNUMYes
# SCPQSTCND  SQCSQC1SCPNUM+NEXQSTYes
# SCPQSTCND  SQCSQC2SCPNUM+QSTNUM+CNDYes
# SCRIPT  SCPSCP0SCPNUMNo
# SDELIVERY  SDHSDH0SDHNUMNo
# SDELIVERY  SDHSDH1BPCORD+BPAADD+DLVDATYes
# SDELIVERY  SDHSDH2DLVDAT+SDHNUMNo
# SDELIVERY  SDHSDH3INVFLG+CFMFLG+SALFCY+BPCINVYes
# SDELIVERY  SDHSDH4CPY+EECNUMDEB+DLVDATYes
# SDELIVERYD  SDDSDD0SDHNUM+SDDLINNo
# SDELIVERYD  SDDSDD1SOHNUM+SOPLIN+SOQSEQYes
# SDELIVERYD  SDDSDD2ITMREF+SHIDAT+SDHNUMYes
# SDELIVERYD  SDDSDD3BPCORD+BPAADD+ITMREFYes
# SDELIVERYD  SDDSDD4SDHNUM-SDDLINYes
# SDELIVERYD  SDDPJMPJT1PJTYes
# SDELIVERYNO  SDNSDN0SDNNUMNo
# SDELIVERYNOD  SDNDSDND0SDNNUM+SDNLINNo
# SEARESULT  LUPLUP0OBJNUMYes
# SEARESULT  LUPLUP1RESNUMYes
# SEARESULT  LUPLUP2SSSYes
# SEARESULT  LUPLUP3OBJNUM+SSSNo
# SEASON  SESSES0SESCODNo
# SEAUTH  SEUSEU0VCRTYP+VCRNUM+VCRSEQNo
# SEAUTH  SEUSEU1TXNIDYes
# SEAUTH  SEUSEU2SOHNUMYes
# SEAUTH  SEUSEU3SDHNUMYes
# SEAUTH  SEUSEU4SIHNUMYes
# SEAUTH  SEUSEU5BPCNUM+ACCNCKNAMYes
# SEBPC  SEBSEB0BPCNUM+ACCNCKNAMNo
# SECACT  SEASEA0CPY+SACNo
# SECPST  SPTSPT0SPTNUMNo
# SECPSTSEL  SPSSPS0SPSNUM+SPSLINNo
# SELACC  SACCSACC0RRCC+CPY+COLTYP+LISNAM+ACCNo
# SELCMG  SECSEC0OPGNUM+SELTBLYes
# SELCMGLIS  SCLSCL0OPGNUM+RECTYPYes
# SELCMGLIS  SCLSCL1OPGNUM+RECTYP+RECNUMYes
# SELCMGLIS  SCLSCL2OPGNUM+RECTYP+RECNUM+BPRNUMYes
# SELSSP  SSPSSP0SPTNUMNo
# SELSSP  SSPSSP1SPTTGR+SPTNUMYes
# SELSSPCPN  SSCSSC0SPTNUM+SPTLEVYes
# SELSSPCPN  SSCSSC1SPTNUM+SPTTABNo
# SENTENCES  RSYRSY0RSYNo
# SEPAR  SEPsept-00JAVSRVNo
# SEPRC  SERSER0PRCCODNo
# SERREQUEST  SRESRE0SRENUMNo
# SERREQUEST  SRESRE1CREDATYes
# SERREQUEST  SRESRE2CREDAT+SRENUMNo
# SERREQUEST  SRESRE3SREBPCYes
# SERREQUEST  SRESRE4SRECCNYes
# SERREQUEST  SRESRE5SREBPC+SRENUMBPCYes
# SERREQUEST  SRESRE6SOLNUMYes
# SERREQUEST  SRESRE7SREORI+SREORIVCR+SREORIVCRLYes
# SERREQUEST  SRESRE8SRERESDAT+SRERESHOU+SREASS+SRENUMNo
# SETMAC  SEMSEM0SETNUM+ITMREFNo
# SETMACCPN  SENSEN0SETNUM+ITMREF+TPYFLGYes
# SETXN  SEXSEX0TXNDATTIM+REQRSP+TXNIDYes
# SETXN  SEXSEX1REF2+TXNDATTIM+REQRSPYes
# SFANAPAR  SFASFA0IDNo
# SFOOTINV  SFISFI0SFINUMNo
# SFTINDREF  SFTIRSFTAG0INDCODNo
# SFTSHIFT  SFTSSHF0SHFCODNo
# SFTTEM  SFTTMSFTTM0TEAMNUM+TEAMLINNo
# SFTTEM  SFTTMSFTTM1TEAMNUM+EMPNUMNo
# SFTTEMH  SFTTHSFTTMH0TEAMNUM+EMPNUM+TEAMSEQNo
# SFTTXN  SFTXSFT0EMPNUM+SFTTYP+VCRNUM+SFTSEQNo
# SFTTXN  SFTXSFT1VCRNUM+OPENUM+CLEFLGYes
# SFTTXN  SFTXSFT2UTCENDDATTIM+VCRNUM+OPENUM+EMPNUM+SFTTYPYes
# SFTTXN  SFTXSFT3UTCSTRDATTIM+VCRNUM+OPENUM+MACFLGYes
# SFTTXN  SFTXSFT4VCRNUM+OPENUMYes
# SFTTXNH  SFTHSFT0EMPNUM+SFTTYP+VCRNUM+SFTSEQ+HISSEQNo
# SFTTXNH  SFTHSFT1UTCSTRDATTIM+VCRNUM+OPENUM+MACFLGYes
# SHIPDOC  SHIPDSHIPD0VCRNUM+VCRTYP+SDLINNo
# SHIPMENT  SHHSHH0SHIPNUMNo
# SHIPMENTD  SHDSHD0SHIPNUM+SHIPLINNo
# SHIPMENTD  SHDSHD1SHIPNUM+CTRNUM+SHIPLINNo
# SHIPMENTD  SHDSHD2POHNUM+POPLIN+POQSEQYes
# SHIPTRACK  SHIPTSHIPT0VCRNUM+VCRTYP+STLINNo
# SINCDET  SNDSND0COD+CODLINNo
# SINCENT  SNESNE0CODNo
# SINVOICE  SIHSIH0NUMNo
# SINVOICE  SIHSIH1BPR+BPRVCRYes
# SINVOICE  SIHSIH2GTE+NUMNo
# SINVOICE  SIHSIH3ACCDAT+BPRYes
# SINVOICE  SIHSIH4BPRFCT+FCTVCR+FCTVCRFLGYes
# SINVOICE  SIHSIH5CUR+BPR+NUMNo
# SINVOICE  SIHSIH6STA+ORIMOD+INVTYP+NUMYes
# SINVOICE  SIHSIH7CPY+EECNUMDEB+ACCDATYes
# SINVOICE  SIHSIH8RCRNUM+RCRDATYes
# SINVOICE  SIHSIH9BVRREFNUMYes
# SINVOICED  SIDSID0NUM+SIDLINNo
# SINVOICED  SIDSID1BPCINV+SALFCY+NUM+SIDLINNo
# SINVOICED  SIDSID2SOHNUM+CREDAT+NUMYes
# SINVOICED  SIDSID3SDHNUM+SDDLINYes
# SINVOICED  SIDSID4CONNUMYes
# SINVOICED  SIDSID5SRHNUMYes
# SINVOICED  SIDPJMPJT1PJTYes
# SINVOICEDLOC  SIDLOCSIDLOC0NUM+SIDLINNo
# SINVOICELOC  SIHLOCSIHLOC0NUMNo
# SINVOICEV  SIVSIV0NUMNo
# SINVOICEV  SIVSIV1SIHORI+SIHORINUMYes
# SINVOICEV  SIVSIV2INVTYP+NUMNo
# SLFPITTMP  SLFTSLFT0SYNNUM+ITMREF+LOT+SLO+STOFCY+PERSTR+VLTNUMNo
# SLOTMD  SLDSLD0VCRNUM+VCRLINNo
# SLOTMH  SLHSLH0VCRNUMNo
# SMVTD  SMDSMD0VCRTYP+VCRNUM+VCRLINNo
# SMVTDVAL  SMVSMV0VCRTYP+VCRNUM+VCRLINNo
# SMVTH  SMHSMH0VCRTYP+VCRNUMNo
# SMVTH  SMHSMH1VCRTYP+IPTDAT+VCRNUMNo
# SNPAFF  SPAFPAF0SNPVCR+OPPNUM+PAFCLBNo
# SNPBUD  SPJBUPJBU0SNPVCR+OPPNUM+PBUCODNo
# SNPBUD  SPJBUPJBU1SNPVCR+OPPNUM+PBUSOR+PBUCODNo
# SNPBUDLIG  SPJLBPJLB0SNPVCR+OPPNUM+PBUCOD+PLBSEQNo
# SNPMSTNEXINV  SPJMSTPJMST0SNPVCR+OPPNUM+TASCOD+PBUCOD+SEQLINNo
# SNPMSTNEXINV  SPJMSTPJMTS1SNPVCR+OPPNUM+PBUCOD+TASCOD+SEQLINNo
# SNPOPEAFF  SPJOAPJOA0SNPVCR+OPPNUM+TASCOD+OPENUM+OPESPLNUM+POANUMNo
# SNPOPPOR  SOPPOPP0SNPVCR+OPPNUMNo
# SNPOPPORPJM  SOPPPJMOPPPJM0SNPVCR+OPPNUMNo
# SNPPIMPL  SPIMPIM0SNPVCR+PIMNUMNo
# SNPTSK  SPJTAPTA0SNPVCR+OPPNUM+TASCODNo
# SNPTSK  SPJTAPTA2SNPVCR+OPPNUM+TASSOR+TASCODNo
# SNPTSKITM  SJTTJTT0SNPVCR+OPPNUM+TASCOD+ITTSEQNo
# SNPTSKLNK  SPTLNKPTLNK0SNPVCR+OPPNUM+TASCOD+SEQNUMNo
# SNPTSKOPE  SPTKOPTKO0SNPVCR+OPPNUM+TASCOD+OPENUM+OPESPLNUMNo
# SNPTSKOPELNK  SOPLNKOPLNK0SNPVCR+OPPNUM+TASCOD+OPENUM+OPESPLNUM+SEQNUMNo
# SOCACTRPT1  SAUR1SAUR10SAURCOD+CPY+FCYNo
# SOI  SOISOI0SOINUMNo
# SOI  SOISOI1FWDSOIYes
# SOI  SOISOI2CPY+FCY+BPR+SOIDAT+SOINUMNo
# SOI  SOISOI3CPY+BPR+CUR+SOINUMNo
# SOI  SOISOI4TYPSOI+NUMSOI+SOINUMNo
# SOLRESULT  SORSOR0SOLNUMYes
# SOLRESULT  SORSOR1NUMYes
# SOLRESULT  SORSOR2SSSYes
# SOLRESULT  SORSOR3SOLNUM+SSS+TYPNo
# SOLUTION  SOLSOL0NUMNo
# SOLUTION  SOLSOL1SRENUMYes
# SORDER  SOHSOH0SOHNUMNo
# SORDER  SOHSOH1BPCORD+CUSORDREFYes
# SORDER  SOHSOH2CUSORDREF+BPCORDYes
# SORDER  SOHSOH3ORDSTA+BPCORDYes
# SORDER  SOHSOH4ORDSTA+SOHNUMNo
# SORDER  SOHSOH5ORDSTA+INVSTA+SOHCATYes
# SORDER  SOHSOH7SOHNUMENDYes
# SORDERC  SOCSOC0SOHNUM+SOPLINNo
# SORDERC  SOCSOC1BPCORD+BPAADD+ITMREFYes
# SORDERC  SOCSOC2CUSORDREF+BPCORD+BPAADD+ITMREFBPCNo
# SORDERP  SOPSOP0SOHNUM+SOPLIN+SOPSEQNo
# SORDERP  SOPSOP1BPCORD+BPAADD+ITMREF+ENDDATYes
# SORDERP  SOPSOP2SOQSTA+SOHCAT+STOFCY+BPCORD+BPAADDYes
# SORDERP  SOPSOP3SOHNUM+SOPLINYes
# SORDERP  SOPSOP4SOQSTA+SOHCAT+SALFCY+BPCINVYes
# SORDERQ  SOQSOQ0SOHNUM+SOPLIN+SOQSEQNo
# SORDERQ  SOQSOQ1STOFCY+SHIDAT+BPCORD+BPAADD+ITMREFYes
# SORDERQ  SOQSOQ2ITMREF+SHIDATYes
# SORDERQ  SOQSOQ3SOQSTA+SHIDAT+DLVPIOCMP+SOHNUM+SOPLIN+SOQSEQNo
# SORDERQ  SOQSOQ4SOQSTA+SOHCAT+STOFCY+BPCORD+BPAADDYes
# SORDERQ  SOQSOQ6SHIDAT+SOHNUM+SOPLIN+SOQSEQNo
# SORDERQ  SOQSOQPJM1PJT+ITMREF+SOHNUM+SOPLIN+SOQSEQNo
# SPACK  SPHSPH0VCRTYP+VCRNUM+PACNUM+PACSEQNo
# SPACK  SPHSPH1VCRTYP+VCRNUM+SCCCODYes
# SPACKD  SPDSPD0VCRTYP+VCRNUM+VCRLIN+PACNUM+PACIND+PACSEQ+VCRSEQNo
# SPACKD  SPDSPD1VCRTYP+VCRNUM+PACSEQ+VCRLIN+PACNUM+PACIND+VCRSEQNo
# SPACKD  SPDSPD2VCRTYP+VCRNUM+VCRLIN+PACNUM+PACIND+VCRSEQ+PACSEQNo
# SPACKD  SPDSPD3VCRTYP+VCRNUM+PACNUM+PACSEQYes
# SPAMOD111  SPM111SPM111CPY+FIY+PER+NUMDECLNo
# SPAMOD115  SPM115SPM115CPY+FIY+PER+NUMDECLNo
# SPAMOD123  SPM123SPM123CPY+FIY+PER+NUMDECLNo
# SPAMOD180  SPM180SPM180CPY+FIY+PER+NUMDECLNo
# SPAMOD1801  SPM1801SPM1801CPY+FIY+PER+NUMDECL+NIFPNo
# SPAMOD190  SPM190SPM190CPY+FIY+PER+NUMDECLNo
# SPAMOD1901  SPM1901SPM1901CPY+FIY+PER+NUMDECL+NIFP+CLAVE+SUBCLAVENo
# SPAMOD193  SPM193SPM193CPY+FIY+NUMDECLNo
# SPAMOD1931  SPM1931SPM1931CPY+FIY+NUMDECL+CONTADORNo
# SPAMOD1932  SPM1932SPM1932CPY+FIY+NUMDECL+CONTADORNo
# SPAMOD216  SPM216SPM216CPY+FIY+PER+NUMDECLNo
# SPAMOD296  SPM296SPM296CPY+FIY+NUMDECLNo
# SPAMOD2961  SPM2961SPM2961CPY+FIY+NUMDECL+CONTADORNo
# SPAMOD303  SPM303SPM303CPY+FIY+PER+NUMDECLNo
# SPAMOD347  SPM347SPM347CPY+FIY+NUMDECLNo
# SPAMOD347D  SPM347DSPM347DCPY+FIY+NUMDECL+CONTADORNo
# SPAMOD349  SPM349SPM349CPY+FIY+PER+NUMDECLNo
# SPAMOD349D  SPM349DSPM349CPY+FIY+PER+NUMDECL+CONTADORNo
# SPAMOD369  SPM369SPM369CPY+FIY+PER+NUMDECLNo
# SPAMOD3691  SPM3691SPM3691CPY+FIY+PER+NUMDECLNo
# SPAMOD3692  SPM3692SPM3692CPY+FIY+PER+NUMDECLNo
# SPAMOD390  SPM390SPM390CPY+FIY+PER+NUMDECLNo
# SPAMOD3901  SPM3901SPM3901CPY+FIY+PER+NUMDECLNo
# SPAMOD3902  SPM3902SPM3902CPY+FIY+PER+NUMDECLNo
# SPAMODCPY  SPMDCSPMDCCPY+CODENo
# SPAMODDET  SPMDETSPMDET0CPY+FIY+PER+MODEL+NUMDECL+LINNo
# SPAMODELS  SPMODSPMODCODENo
# SPASENDINQ  SPSINQSPSINQ0MODEL+CPY+FIY+PER+NUMDECLNo
# SPLIBREG  SPLREGSPLREG0CPY+RECTYP+REGTYP+INVNUM+VATNo
# SPLIBREG  SPLREGSPLREG1CPY+RECTYP+REGTYP+FIY+PERYes
# SPPRTCONF  SPPSPP0CODNo
# SPREASON  SPRSPR0PRIRENNo
# SPRICCONF  SPCSPC0PLINo
# SPRICCONF  SPCSPC1PLIENAFLG+PLITYP+PIO+PLINo
# SPRICFICH  SPFSPF0PLI+PLICRDNo
# SPRICINCR  SPISPI0PLI+PLICRD+PLILINNo
# SPRICLINK  SPKSPK0CLENo
# SPRICLIST  SPLSPL0PLI+PLICRD+PLILINNo
# SPRICLIST  SPLSPL1PLI+PLICRI+PLISTRDATYes
# SPRICLIST  SPLSPL2PLI+PLICRI1+PLISTRDATYes
# SPRICLIST  SPLSPL3PLI+PLICRI2+PLISTRDATYes
# SPRICLIST  SPLSPL4PLI+PLICRI1+PLICRI2+PLICRI3+PLICRI4+PLICRI5Yes
# SPRICPRTQ  SPQSPQ0COD+BPCORD+ITMREF+SPQLINNo
# SPRICPRTQ  SPQSPQ1COD+ITMREF+BPCORD+SPQLINNo
# SQUOTE  SQHSQH0SQHNUMNo
# SQUOTE  SQHSQH1BPCORD+CUSQUOREFYes
# SQUOTE  SQHSQH3SQHNUMENDYes
# SQUOTED  SQDSQD0SQHNUM+SQDLINNo
# SQUOTED  SQDSQD1ORDFLG+SALFCY+BPCORDYes
# SQUOTED  SQDPJMPJT1PJTYes
# SREMAC  SRMSRM1SRENUM+MACNUMNo
# SREMACCPN  SRNSRN0SRENUM+MACNUM+TPYFLGYes
# SRESAT  SRSSRS0SRENUMYes
# SRESTAT  SSTSST0USRYes
# SRETEMPL  SETSET0SETNUMNo
# SRETURN  SRHSRH0SRHNUMNo
# SRETURN  SRHSRH1SDHNUMYes
# SRETURN  SRHSRH2CPY+EECNUMDEB+RTNDATYes
# SRETURN  SRHSRH3RTNDAT+SRHNUMNo
# SRETURND  SRDSRD0SRHNUM+SRDLINNo
# SRETURND  SRDSRD1SDHNUM+SDDLINYes
# SRETURND  SRDSRD2SIHNUM+RTNCNOFLGYes
# SRETURND  SRDPJMPJT1PJTYes
# STAT  SATSAT0COD+CPY+FCY+DAT+CRI1+CRI2+CRI3+CRI4+CRI5+CRI6+CRI7+CRI8No
# STATION  STXSTX0STINo
# STATIONBOX  SBXSBX0BOX+FCYNo
# STATIONBOX  SBXSBX1STI+BOXYes
# STATPRV  SAPSAP0COD+CPY+FCY+DAT+CRI1+CRI2+CRI3+CRI4+CRI5+CRI6+CRI7+CRI8No
# STJTMP  SJTSJT0ENTCOD+CPY+KEY1+KEY2+KEY3+KEY4+KEY5+STOFCY+UPDCOD+ITMREF+IPTDAT-MVTSEQ-MVTINDNo
# STKMVTADJ  SMASMA0VCRNUM+VCRLIN+VCRTYP+STOFCY+VCRNUMREG+VCRLINREG+VCRTYPREG+ITMREF+LOT+SLONo
# STKMVTADJ  SMASMA1LLC+NUMNo
# STKMVTADJ  SMASMA2NUMNo
# STKMVTITC  SMISMI0ITCSTRDAT+ITMREF+STOFCY+CSTTYPNo
# STKREGWRK  SRWSRW0VCRNUM+VCRLIN+VCRTYP+CREMVTSEQ+CPY+ITMREF+LOT+SLONo
# STKTRS  SRTSRT0SRTTYP+SRTNUMNo
# STKTRS  SRTSRT1SRTNUM+SRTTYPNo
# STOACCPAR  SACSAC0PRODAT+FINFCYNo
# STOADCSEARCH  SASSAS0STOFCY+FLWTYPNo
# STOALL  STASTA0STOFCY+ITMREF+STOCOU+SEQNo
# STOALL  STASTA1VCRTYP+VCRNUM+VCRLIN+VCRSEQ+STOCOUYes
# STOALL  STASTA2ITMREF+VCRTYP+VCRNUM+VCRLIN+VCRSEQ+ALLTYP+STOFCYYes
# STOCK  STOSTO0STOFCY+STOCOUNo
# STOCK  STOSTO1STOFCY+PALNUM+ITMREFYes
# STOCK  STOSTO3ITMREF+STOFCY+LOT+SLO+LOCYes
# STOCK  STOSTO4STOFCY+LOCYes
# STOCK  STOSTO5ITMREF+SERNUMYes
# STOCK  STOSTO6LPNNUM+ITMREF+STOCOUYes
# STOCOST  STPSTP0ITMREF+STOFCY+CSTDAT+CSTTIM+CSTCOUNo
# STOCOST  STPSTP1ITMREF+STOFCY+VCRTYP+VCRNUM+VCRLINYes
# STOCOSTPIT  STPPSTPP0ITMREF+STOFCY+CSTDAT+CSTTIM+CSTCOU+PERSTR+VLTNUMNo
# STOJOU  STJSTJ0STOFCY+UPDCOD+ITMREF-IPTDAT+MVTSEQ+MVTINDNo
# STOJOU  STJSTJ1STOFCY+VCRTYP+VCRNUM+VCRLINYes
# STOJOU  STJSTJ2UPDCOD+ITMREF-IPTDAT+MVTSEQ+MVTINDYes
# STOJOU  STJSTJ3UPDCOD-CREDAT-CRETIM+ITMREFYes
# STOJOU  STJSTJ4ITMREF+IPTDAT+CREMVTDAT+CREMVTTIM+CREMVTSEQYes
# STOJOUOVE  SJOSJV0STOFCY+UPDCOD+ITMREF-IPTDAT+MVTSEQ+MVTIND+OVENATNo
# STOJOUVAL  SJVSJV0STOFCY+UPDCOD+ITMREF-IPTDAT+MVTSEQ+MVTINDNo
# STOLOC  STCSTC0STOFCY+LOCNo
# STOLOC  STCSTC1STOFCY+OCPCOD+LOCTYP+PPSSEQNo
# STOLOC  STCSTC2STOFCY+LOCTYP+PPSSEQNo
# STOLOC  STCSTC3STOFCY+LOCTYP+LOCNo
# STOLOC  STCSTC4STOFCY+LOCCAT+LOCTYP+LOCNo
# STOLOC  STCSTC5STOFCY+WRH+LOCNo
# STOLOCAFF  STFSTF0STOFCY+LOC+ITMREFNo
# STOLOCAFF  STFSTF1STOFCY+ITMREF+LOCNo
# STOLOCRES  SWLSWL0PRONUM+LINNUMNo
# STOLOCRES  SWLSWL1STOFCY+LOCYes
# STOLOT  STLSTL0ITMREF+LOT+SLONo
# STOLOT  STLSTL1ITMREF+LOTCREDAT+LOT+SLONo
# STOLOT  STLSTL2ITMREF+SHLDAT+LOTCREDAT+LOT+SLONo
# STOLOT  STLSTL3SHLDAT+ITMREF+LOT+SLONo
# STOLOTFCY  SLFSLF0ITMREF+LOT+SLO+STOFCYNo
# STOLOTFCYPIT  SLFPSLFP0ITMREF+LOT+SLO+STOFCY+PERSTR+VLTNUMNo
# STOMVTCOST  SMCSMC0CSTCOU+CSTTIM+CSTDAT+VCRNUM+VCRLIN+VCRTYPNo
# STOMVTCOST  SMCSMC1CSTCOU+CSTTIM+CSTDATYes
# STOPAR  STESTE0STOFCY+TCLCODNo
# STOPRED  PREPRE0PRHNUM+PRELINNo
# STOPRED  PREPRE1ORINUM+ORILIN+ORISEQYes
# STOPREH  PRHPRH0PRHNUMNo
# STOPREH  PRHPRH1STOFCY+DLVFLG+PRHNUMNo
# STOPREH  PRHPRH2STOFCY+PRLNUM+DLVFLG+PRHNUMNo
# STOPREH  PRHPRH3SDHNUM+PRHNUMNo
# STOPRELIS  PRLPRL0PRLNUM+PRLSEQNo
# STOPRELIS  PRLPRL1ORITYP+ORINUM+ORILIN+ORISEQYes
# STOPRELIS  PRLPRL2PRHNUM+PRELIN+PRLNUM+PRLSEQYes
# STOPRELISW  PLWPLW0PRONUM+WKEY+ORITYP+ORI1+ORI2+ORI3No
# STOPREW  PRWPRW0PRONUM+WKEY+ORITYP+ORI1+ORI2+ORI3No
# STOPREW  PRWPRW1PRONUM+WKEY+WKEYD+ORITYP+ORI1+ORI2+ORI3No
# STOQLYD  QLDQLD0VCRTYP+VCRNUM+VCRLINNo
# STOQLYD  QLDQLD1ITMREF+STOFCY+VCRTYP+VCRNUM+VCRLINNo
# STOQLYD  QLDQLD2VCRTYP+VCRNUM+LOT+SLO+SERNUMYes
# STOQLYD  QLDQLD3VCRTYP+VCRNUM+VCRLINORI+SERNUMYes
# STOQLYH  QLHQLH0VCRTYP+VCRNUMNo
# STOQLYH  QLHQLH1STOFCY+ITMREF+VCRNUMNo
# STOQLYH  QLHQLH2VALFLG+VCRTYP+VCRNUMNo
# STOQLYH  QLHQLH3VCRTYPORI+VCRNUMORI+ITMREFYes
# STOQLYSMP  SMPSMP0VCRTYP+VCRNUM+ITMREF+LOTNo
# STOQUAL  STQSTQ0QLYCTLDEMNo
# STOQUAL  STQSTQ1ITMREF+LOT+QLYCTLDEMNo
# STOREO  REOREO0STOFCY+LOC+ITMREFNo
# STOREO  REOREO1VCRTYP+VCRNUM+VCRLINYes
# STOREO  REOREO2VCRNUM+VCRLINYes
# STOSER  STSSTS0ITMREF+SERNUMNo
# STOSER  STSSTS2ITMREF+SDHTYP+SDHNUM+SDDLIN+SERNUMNo
# STOSER  STSSTS3ITMREF+STOCOU+SERNUMNo
# STOSERW  SSWSSW0ITMREF+SERNUMNo
# STOSERW  SSWSSW1PRONUM+ITMREF+SERNUMNo
# STOSRG  SRGSRG0STOCOU+VCRTYP+VCRNUM+VCRLINNo
# STOSRG  SRGSRG1STOFCY+ITMREFYes
# STOSRG  SRGSRG2STOFCY+LOCYes
# STOSRG  SRGSRG3STOFCY+VCRTYP+VCRNUM+VCRLINYes
# STOSRG  SRGSRG4STOFCY+SRGPPSYes
# STOSRG  SRGSRG5STOFCY+VCRNUM+VCRLINYes
# STOSRGW  SGWSGW0STOCOU+VCRTYP+VCRNUM+VCRLIN+SRGSEQNo
# STOSYNW  SYWSYW0CUNLISNUM+STOFCY+ITMREF+SEQNo
# STOSYNW  SYWSYW1STOFCY+ITMREF+LOT+SLO+LOC+STAYes
# STOSYNW  SYWSYW2STOFCY+ITMREF+SERNUMYes
# STOTRK  STRSTR0ITMREF+LOT+SLO-IPTDAT+MVTSEQ+STOFCYNo
# STOTRK  STRSTR1VCRTYP+VCRNUM+VCRLINYes
# STOTRK  STRSTR2ITMREF+SERNUM-IPTDAT+MVTSEQ+STOFCYYes
# STOTRKWRK  SKWSKW0PRONUM+LEVNo
# STOTRKWRK  SKWSKW1CREUSR+CREDAT+PRONUM+LEVNo
# STOVALCUM  SVCSVC0PRONUM+STOFCY+TCLCOD+TSINUM+TSICOD+BUYNo
# STOVALWRK  STVSTV0CREUSR+PRONUM+ITMREF+STOFCY+LOT+STOCOUNo
# STOWIPW  SWWSWW0STOCOU+PRONUM+SEQNo
# STPPITTMP  STPTSTPT0SYNNUM+ITMREF+STOFCY+CSTDAT+CSTTIM+CSTCOU+PERSTR+VLTNUMNo
# SUBCONT  PRXPRX0BPRNUMNo
# SVATCTL  SVATSVAT0ROOTACC+TAXCOD+LEDTYPENo
# SVCRFOOT  SVFSVF0VCRNUM+VCRTYP+DTANo
# SVCRFOOT  SVFSVF1VCRTYP+VCRNUM+DTANo
# SVCRFOOT  SVFSVF2VCRTYP+VCRNUM+CLCORD+DTANo
# SVCRFOOT  SVFSVF3NUM+VCRTYP+VCRNUM+DTANo
# SVCRFOOTLOC  SVFLOCSVFLOC0VCRNUM+VCRTYP+DTANo
# SVCRINVCND  SVICSVIC0VCRTYP+VCRNUMORI+VCRLINORI+VCRSEQORINo
# SVCRINVCND  SVICSVIC1VCRTYP+VCRNUMORIYes
# SVCRINVCND  SVICSVIC2VCRTYP-VCRNUMORI+VCRLINORI+VCRSEQORINo
# SVCRINVCND  SVICSVIC3SVICNUMNo
# SVCRINVCNDD  SVICDSVICD0VCRTYP+VCRNUMORI+VCRLINORI+VCRSEQORI+VCRINVCNDLINNo
# SVCRINVCNDD  SVICDSVICD1VCRTYP+VCRNUMORI+VCRLINORI+VCRSEQORIYes
# SVCRINVCNDD  SVICDSVICD2VCRTYP+VCRNUMORIYes
# SVCRINVCNDD  SVICDSVICD3VCRTYP-VCRNUMORI+VCRLINORI+VCRSEQORI+VCRINVCNDLINNo
# SVCRINVCNDD  SVICDSVICD4VCRNUMORI+VCRLINORI+NEXINVDAT+VCRINVCNDLINYes
# SVCRINVCNDD  SVICDSVICD5SVICNUM+VCRINVCNDLINNo
# SVCRINVCNDD  SVICDSVICD6VCRTYP+VCRNUMORI+VCRLINORI+VCRSEQORI+NEXINVDAT-INVCNDQTY+VCRINVCNDLINNo
# SVCRVAT  SVVSVV0VCRTYP+VCRNUM+VATNo
# SVCRVAT  SVVSVV1VCRTYP+VCRNUM+VATTYP+VATNo
# SVCRVAT  SVVSVV2NUM+VCRTYP+VCRNUM+VATNo
# SVCRVATLOC  SVVLOCSVV0VCRTYP+VCRNUM+VATNo
# SWIEZAG  SWIEZSWIEZ0DATNo
# SWIIMPBVR  SWIIMPSWIIMP0NUMIMP+LINENo
# SWIIMPTMP  SWITMPSWITMP0NUMIMP+LINENo
# SWIIMPTMP  SWITMPSWITMP1NUMIMP+CUR+NUMMICROYes
# SWIQRC  SWIQRCSWIQRC0NUM+ORIMODNo
# SWIQRC  SWIQRCSWIQRC1REF+ORIMODYes
# SWRKDLV  SWDSWD0PRONUM+SWDKEY+SOHNUM+SOPLIN+SOQSEQNo
# SWRKDLV  SWDSWD1PRONUM+SOHNUMYes
# SWRKINV  SWISWI0PRONUM+SWIKEY+SWIKEY1+NUM+LIN+SEQNo
# SWRKINV  SWISWI1PRONUM+NUMYes
# SWRKINVCND  SWICNDSWI0PRONUM+SWIKEY+SWIKEY1+NUM+LIN+SEQ+VCRINVCNDLINNo
# SWRKINVCND  SWICNDSWI1PRONUM+NUMYes
# SYNCDATA  SYDSYD0SYDNUMNo
# SYNCDATA  SYDSYD1SYDUSRYes
# SYNCLINK  SYLSYL0SYLNUMNo
# SYNCPAR  SYPSYP0SYPUSRNo
# TAAAXXX  XXXXXX0XXXNUMNo
# TABACCINT  TCITCI0CPYSRC+CPYTGR+FCYSRC+FCYTGRNo
# TABACCLIK  TCKTCK0COA+FCY1+FCY2No
# TABALLRUL  TRUTRU0TRUCODNo
# TABBOMALT  TBOTBO0BOMALTTYP+BOMALTNo
# TABBOMALT  TBOTBO1FCY+BOMALT+BOMALTTYPNo
# TABBOMALT  TBOTBO2BOMALT+BOMALTTYPNo
# TABBUDTYP  TBUTBU0BUDTYP+COLNUMNo
# TABBUDTYP  TBUTBU1BUDTYP+LINSELCRIYes
# TABCABCUT  CUTCUT0FCYNo
# TABCHANGE  TCHTCH0CHGTYP+CURDEN+CUR+CHGSTRDATNo
# TABCHANGE  TCHTCH1CHGTYP+CURDEN+CHGSTRDAT+CURNo
# TABCODEDT  TEDTED0CODEDT+LEGNo
# TABCOEFF  TCOTCO0UOM1+UOM2No
# TABCONTAINER  TCTRTCTR0TCTRNUMNo
# TABCOSTMET  TCMTCM0VLTCODNo
# TABCOSTMVT  TVMTVM0VLTCOD+MVTTYP+TRSCODYes
# TABCOSTMVT  TVMTVM1VLTCOD+NUM+MVTTYP+TRSCODNo
# TABCOUAFF  TCATCA0MODULE+LEG+CPYNo
# TABCOUNTRY  TCYTCY0CRYNo
# TABCTL  TCTTCT0TCT+TCTLINNo
# TABCTL  TCTTCT1TCT+ALPCOD+NUMCODNo
# TABCUR  TCUTCU0CURNo
# TABDEPAGIO  TDATDA0DEP+LEGNo
# TABDEPAGIO  TDATDA1DEPYes
# TABEECNAT  TECTEC0EECNAT+LEGNo
# TABEECSCH  TSCTSC0EECSCH+LEGNo
# TABEXPENS  TESTES0CODEXPNo
# TABFILBAN  TFBTFB0COD+BAN+RECTYP+ORDNUM+LEG+NUMNo
# TABFILCASH  TFCTFC1MODULE+CODCAS+CODPARNo
# TABFILCASH  TFCTFC2MODULE+CODCASYes
# TABFILCASH  TFCTFC3MODULE+CODPAR+CODCASNo
# TABFILTDS  TFTTFT0COD+RECTYP+NUMNo
# TABFOR  TFOTFO0FORTYP+FORCODNo
# TABFORLEG  TFOLEGTFOLEG0FORCOD+LEGNo
# TABGEOCOD  TGETGE0GEOCODNo
# TABINVCND  INVCNDINVCND0INVCND+LEGNo
# TABINVCND  INVCNDINVCND1INVCNDYes
# TABINVCNDLIN  INVCNDDINVCNDD0INVCND+LEG+INVCNDLINNo
# TABINVCNDLIN  INVCNDDINVCND1INVCND+INVCNDLINYes
# TABINVCNDLIN  INVCNDDINVCND2INVCND+LEGYes
# TABLAN  TLATLA0LANNo
# TABLINCFG  TLPTLP0CFGLINNo
# TABLOCTYP  TLOTLO0STOFCY+LOCTYPNo
# TABLOCTYP  TLOTLO1STOFCY+LOCCAT+LOCTYPNo
# TABMAT  TMATMA0EMPNUMNo
# TABMAT  TMATMA1USRYes
# TABMODELIV  TMDTMD0MDLNo
# TABMSG  TMSTMS0MSGNUMNo
# TABPACKAGE  TPATPA0PCKNo
# TABPAM  TAMTAM0PAM+LEGNo
# TABPAYTERM  TPTTPT0PTE+LEG+PTELINNo
# TABPAYTERM  TPTTPT1PTE+PTELINYes
# TABPAYTERM  TPTTPT2PTE+LEGYes
# TABPAYTYP  TPYTPY0PAYTYP+LEGNo
# TABPIVTYP  TPVTPV0PIVTYP+LEGNo
# TABPLACE  TPCTPC0TPCNo
# TABPLACETIME  TPCTTPCT0DPETPC+ARVTPC+TRNTPC+BPTNUMNo
# TABPNHTYP  TPNTPN0PNHTYP+LEGNo
# TABPNHTYP  TPNTPN1PNHTYPYes
# TABPRECOD  PRCPRC0STOFCY+NUMCRIT+PRECODNo
# TABPRECOD  PRCPRC1STOFCY+PRECODYes
# TABPRTMOD  TPMTPM0TPMCODNo
# TABRATVAT  TRATRA0VAT+LEG+CPY+STRDATNo
# TABRATVAT  TRATRA1VAT+CPY+STRDATYes
# TABREOPOL  TRPTRP0REOPOLNo
# TABROUALT  TROTRO0ROUALTNo
# TABROUALT  TROTRO1FCY+ROUALTNo
# TABROUND  TRNTRD0RNDCODNo
# TABSAFSTO  TSATSA0SRVRATNo
# TABSCA  TSRTSR0SCANUMNo
# TABSDHTYP  TSDTSD0SDHTYP+LEGNo
# TABSGHTYP  TSGTSG0SGHTYP+LEGNo
# TABSGHTYP  TSGTSG1SGHTYPYes
# TABSIVTYP  TSVTSV0SIVTYP+LEGNo
# TABSIVTYP  TSVTSV1SIVTYPYes
# TABSOHTYP  TSOTSO0SOHTYP+LEGNo
# TABSOHTYP  TSOTSO1SOHTYPYes
# TABSQHTYP  TSQTSQ0SQHTYP+LEGNo
# TABSQHTYP  TSQTSQ1SQHTYPYes
# TABSRHTYP  TRETRE0SRHTYP+LEGNo
# TABSRHTYP  TRETRE1SRHTYPYes
# TABSTASTO  TSTTST0STASTONo
# TABSTORUL  SRUSRU0TCLCOD+STOFCY+TRSTYP+TRSCODNo
# TABSUBDIV  ATUATU0CRY+TYP+CODNo
# TABTNHTYP  TTNTTN0TNHTYP+LEGNo
# TABTNHTYP  TTNTTN1TNHTYPYes
# TABUNAVAIL  TUVUVY0UVYCODNo
# TABUNIT  TUNTUN0UOMNo
# TABUNNBR  TUNNBTUNNB0UNNBRNo
# TABVAC  TVCTVC0COD+LEGNo
# TABVAC  TVCTVC1VACBPR+VACITMYes
# TABVAC  TVCTVC2VATTYP-ENAFLG-LEG-GRP-VACBPR-VACITM+CODNo
# TABVACBPR  TVBTVB0VACBPR+LEGNo
# TABVACITM  TVITVI0VACITM+LEGNo
# TABVAT  TVTTVT0VAT+LEGNo
# TABVAT  TVTTVT1VATYes
# TABVATEXE  TEXTEX0BPCNUM+NUMORDNo
# TABWEEDIA  TWDTWD0TWDNo
# TABWIPSTO  TWSTWS0STOCOU+STOSEQNo
# TABWIPSTO  TWSTWS1STOFCY+ITMREFYes
# TABWIPSTO  TWSTWS2VCRTYP+VCRNUM+VCRLINYes
# TABWRKCTR  TWCTWC0WCRNo
# TABWRKCTR  TWCTWC1WCRDESYes
# TACONTAINERC  TCTRCTCTRC0TCTRNUMNo
# TANKS  TKSTKS0TKS+FCYNo
# TANKSGATES  TGTTGT0TGTTKS+FCY+TGTLINNo
# TANKSGATES  TGTTGT1TGTTKS+FCY+TGTGTSNo
# TASK  TSKTSK0TSKNUMNo
# TASK  TSKTSK1TSKDAT+TSKNUMNo
# TASK  TSKTSK2TSKCMPYes
# TASK  TSKTSK3TSKCCNYes
# TASK  TSKTSK4TSKREP+TSKDAT+TSKNUMNo
# TASK  TSKTSK5CREUSRYes
# TAXLINK  TLKDLK0CLENo
# TCBLOB  TBBTBB0CODBLB+IDENT1+IDENT2+IDENT3No
# TCCLOB  TBCTBC0CODCLB+IDENT1+IDENT2+IDENT3No
# TDSPRV  TPRTPR0PRVNUM+CPYNo
# TDUPDCLC  TUCTUC0MFGNUMNo
# TEXCLOB  TXCTXC0CODENo
# TEXCLOB  TXCTXC1IDENT1+IDENT2+IDENT3Yes
# TEXCPT  TCCTCC0ABRFICNo
# TGRLIS  TGLTGL0TGRTABNo
# TGRLISFIE  TLFTLF0TGRTAB+TGRSSPNUMYes
# TGRLISFIE  TLFTLF1TGRTAB+TGRSSPNUM+TGRTABLNK+TGRFIENo
# TGRLISLNK  TLLTLL0TGRTAB+TGRLNKNo
# TGRLISLNK  TLLTLL1TGRTAB+TGRLNK+TGRLNKIDXNo
# TGRSSP  TGPTGP0TGRSSPNUMNo
# TGRSSP  TGPTGP1TGR+TGRSSPNUMYes
# TIMEADJUST  TADTAD0COD+STRDATNo
# TIMETRANS  TTRTTR0CODNo
# TIMEZONEINFO  TZITZI0CODNo
# TIMEZONEINFO  TZITZI1UTCOFFSET+CODNo
# TMP2054  T54T540EDTNUM+CPY+CLATXS+POSTXSNo
# TMP2055  T55T550EDTNUM+CPY+CLATXS+POSTXSNo
# TMP2855  TVST550EDTNUM+CPY+IMPSTRDAT+AASREFNo
# TMP28578  TVS2T5780EDTNUM+CPY+IMPSTRDAT+AASREFNo
# TMPARPT  TARPTTARPT0NUMREQ+USR+RPTCOD+VCRNUMNo
# TMPARPTDET  TARPTDTSRPTD0NUMREQ+USR+RPTCOD+VCRNUM+LINNo
# TMPBLA  TBLARM0NUMREQ+USR+RPTCOD+NUMLIGNo
# TMPBLA  TBLARM1USR+RPTCODYes
# TMPCNSBAN  TCBTCB0TCBNUMNo
# TMPCNSBAN  TCBTCB1USRCRE+ADXNUMYes
# TMPCNSBAN  TCBTCB2ACCNUMYes
# TMPCNSBAN  TCBTCB3NUMPAY+USRCRE+ADXNUMYes
# TMPCNSESL1  TESL1TESL10USERID+EECNUM+SALTYPCOD+CRYNo
# TMPCNSESL1  TESL1TESL11USERIDYes
# TMPCNSESL2  TESL2TESL20USERID+SEQNo
# TMPCNSESL2  TESL2TESL21USERID+EECNUM+SALTYPCODYes
# TMPCNSESL2  TESL2TESL22USERID+EECNUM+SALTYPCOD+CRY+CPY+FCYLIN+OFFACC+TAX+TYP+NUM+LIN+ACC+SEQNo
# TMPCNVECAR  TCETCE0LEDTYP+SOC+SITE+NUM+DEVNo
# TMPCPTDTA  TCDTCD0TRTNUM+PCENUM+SEQNUM+DSP+CCENo
# TMPCRPT  TCRPTTCRPT0NUMREQ+USR+RPTCOD+VCRNUMNo
# TMPCSRQ  TCRTCR0CREUSR+BPR+FCY+TYP+NUM+DUDDAT+DUDLIGNo
# TMPDERO  TDETDE0EDTNUM+CPY+FCY+AASREFNo
# TMPDERO  TDETDE1EDTNUM+AASREFNo
# TMPDFD  TDFTDF0EDTNUM+CPY+FCY+AASREFNo
# TMPDFD  TDFTDF1EDTNUM+AASREFNo
# TMPEXPENSE  EXTEXT0CPY+CUR+BPRGTETYP+FCY+SEP+DATEXSYes
# TMPEXPENSE  EXTEXT1ACCNUMNo
# TMPFAS1PAGE  T1PGT1P0CPY+AASREFYes
# TMPFAS246G  T246T2460CPY+AASREF+DPRPLN+POSTXSYes
# TMPFASLIST  TFLTFL0EDTNUM+AASREFNo
# TMPFASLIST  TFLTFL1EDTNUM+CPY+FCY+AASREFNo
# ...
# «For [F:Table] Order By [Champ] Asc|Desc»' metadata={'h1': 'Manipulation des données, «Where», «Filter»,»Order by»', 'h2': 'Utilisation de la Clause Order By', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Le Trans-Classe est utilisé ici pour simplifier la copie des données entre la table source et le masque de l'écran. Cependant, dans des cas où les noms des champs dans la source et la destination ne correspondent pas exactement, ou lorsque des champs spécifiques requièrent un traitement conditionnel, une alimentation champ par champ devient nécessaire. Cette méthode est également utilisée pour gérer les champs dimensionnés et conditionnels :
# «# Alimentation conditionnelle basée sur la présence et la dimension des champs
# If dim([M:BPC4]REP0)>0 [M:BPC4]REP0(nolign-1) = [F:BPD]REP(0) endif
# If dim([M:BPC4]REP1)>0 [M:BPC4]REP1(nolign-1) = [F:BPD]REP(1) endif»' metadata={'h1': 'Mise à jour de la variable de bas de tableau', 'h3': 'Trans-Classe et Alimentation Champ par Champ', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Avant toute manipulation, le script s'assure que toutes les tables nécessaires sont ouvertes. Cette étape est cruciale car tenter d'accéder à une table non ouverte entraînerait une erreur.
# plaintext
# Copy code
# If clalev([F:ZRCL])=0 : Local File ZRECUPCLT [F:ZRCL] : Endif
# If clalev([F:ZDPO])=0 : Local File ZDEPOT [F:ZDPO] : Endif
# If clalev([F:ZAI])=0 : Local File ZADREPI [F:ZAI] : Endif
# If clalev([F:ZAI2])=0 : Local File ZADREPI [F:ZAI2] : Endif
# Ces lignes garantissent que chaque table est accessible pour les opérations suivantes, et chaque table est ouverte seulement si elle n'a pas déjà été ouverte (clalev vérifie le niveau d'accès actuel).' metadata={'h1': 'L’utilisation du Transactionnel pour les modifications de Tables en L4G', 'h2': "Analyse et Explication d'un Script de Gestion Transactionnelle dans Sage X3", 'h3': 'Ouverture des Tables et Initialisation des Variables', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='L'instruction Read en L4G permet de récupérer un enregistrement spécifique d'une table en utilisant une clé d'index prédéfinie. La syntaxe générale de cette commande est :
# «Read [F:NomTable]Index = Valeur1; Valeur2; ...»
# [F:NomTable] : C'est l'abréviation de la table dans laquelle la recherche est effectuée.
# Index : La clé d'index spécifiée pour la recherche.
# Valeur1; Valeur2; ... : Les valeurs correspondant aux différents champs de l'index, utilisées pour localiser l'enregistrement désiré.' metadata={'h1': "Comprendre l'Instruction Read", 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Table | Table name | Primary key | Relation fields | Table linked | Table linked description | Table linked primary key
# SFI - SFOOTINV | Invoicing elements | SFI0: SFINUM | INVDAT.[1..9] | PRS - PRICSTRUCT | Price structure (cost/supp) | PRS0: PLI/STC
# SPR - SPREASON | Sales price list reasons | SPR0: PRIREN | PRIREN | PRS - PRICSTRUCT | Price structure (cost/supp) | PRS0: PLI/STC
# SPC - SPCONF | Customer pricing parameters | SPC0: PLU | PLU | SPF - SPRICFICH | Customer prices (records) | SPF0: PLU/PLCRD
# SPF - SPRICFICH | Customer prices (records) | SPF0: PLU/PLCRD | PLU/PLCRD | SPL - SPPRICLIST | Customer price lists | SPL0: PLU/PLCRD
# SPL - SPPRICLIST | Customer price lists | SPL0: PLU/PLCRD | PLICRID | ITM - ITMMASTER | Products | ITM0: ITMREF
# SPL - SPPRICLIST | Customer price lists | SPL0: PLU/PLCRD | PLICRID | BPC - BPCUSTOMER | Customers | BPC0: BPCNUM
# TCU - TABCUR | Currency table | TCU0: CUR | CUR | PRS - PRICSTRUCT | Price structure (cost/supp) | PRS0: PLI/STC
# SFI - SFOOTINV | Invoicing elements | SFI0: SFINUM | INVDAT.[1..9] | PRS - PRICSTRUCT | Price structure (cost/supp) | PRS0: PLI/STC
# PRS - PRICSTRUCT | Price structure (cost/supp) | PRS0: PLI/STC | PLI/STC | SPC - SPCONF | Customer pricing parameters | SPC0: PLU
# PRS - PRICSTRUCT | Price structure (cost/supp) | PRS0: PLI/STC | PLI/STC | TCU - TABCUR | Currency table | TCU0: CUR
# SPR - SPREASON | Sales price list reasons | SPR0: PRIREN | PRIREN | PRS - PRICSTRUCT | Price structure (cost/supp) | PRS0: PLI/STC
# SPC - SPCONF | Customer pricing parameters | SPC0: PLU | PLU | SPF - SPRICFICH | Customer prices (records) | SPF0: PLU/PLCRD
# SPF - SPRICFICH | Customer prices (records) | SPF0: PLU/PLCRD | PLU/PLCRD | SPL - SPPRICLIST | Customer price lists | SPL0: PLU/PLCRD
# SPL - SPPRICLIST | Customer price lists | SPL0: PLU/PLCRD | PLICRID | ITM - ITMMASTER | Products | ITM0: ITMREF
# SPL - SPPRICLIST | Customer price lists | SPL0: PLU/PLCRD | PLICRID | BPC - BPCUSTOMER | Customers | BPC0: BPCNUM
# ITM - ITMMASTER | Products | ITM0: ITMREF | ITMREF | SPL - SPPRICLIST | Customer price lists | SPL0: PLU/PLCRD
# BPC - BPCUSTOMER | Customers | BPC0: BPCNUM | BPCNUM | SPL - SPPRICLIST | Customer price lists | SPL0: PLU/PLCRD' metadata={'h1': 'SALES 7 - SALES PRICE', 'source': 'X3_RELATIONSHIPS.md'}
#
#
# page_content='IMPORTANT :
# This document is based on the standard data model of Sage X3 and may contain errors as it is an AI translation from images.
# Throughout the document, tables are generally represented in the form XXX - YYYYYYYYYY where XXX is the abbreviated code of the table and YYYYYYYYYY is the actual code of the table in the database.
# For fields, sometimes the notation AAAA: BBBBBBBBBB is used, where AAAA indicates the index code and BBBBBBBBBB indicates the field code.
# This document, though assisted by AI, bears the mark of Guillaume Clément's passionate dedication, which spanned countless hours.' metadata={'source': 'X3_RELATIONSHIPS.md'}
#
#
# page_content='La syntaxe générale pour créer une jointure avec Link est la suivante :
# «Link [F:TablePrincipale] With [F:TableLiee]KEY0~=FIELD1TableLiee;FIELD2TableLiee As [Abreviation]
# & Where [Conditions]
# & Order By [Critères de Tri]»
# Table Principale et Tables Liées : Avant de définir un Link, il est impératif que toutes les tables impliquées soient ouvertes. Sage X3 ne permet pas d'ouvrir les tables dans le cadre de l'instruction Link ; elles doivent être ouvertes au préalable dans le script.' metadata={'h1': 'Opération CRUDE en base de données', 'h2': "Fonctionnement de l'Instruction Link", 'h3': 'Syntaxe de Base du Link', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='La transaction est initiée avec Trbegin et inclut toutes les tables qui seront modifiées. Cela prépare le système à gérer toutes les modifications de manière atomique, c'est-à-dire que toutes les modifications seront appliquées ou aucune ne le sera si une erreur survient.
# plaintext
# Copy code
# Trbegin [F:ZDPO],[F:ZAI],[F:ZAI2]
# Il est important de noter que le Trbegin inclut les tables en argument pour spécifier explicitement les tables impliquées dans la transaction, conformément aux meilleures pratiques.' metadata={'h1': 'L’utilisation du Transactionnel pour les modifications de Tables en L4G', 'h2': "Analyse et Explication d'un Script de Gestion Transactionnelle dans Sage X3", 'h3': 'Début de la Transaction', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Table | Table name | Primary key | Relation fields | Table linked | Table linked description | Table linked primary key
# TCU - TABCUR | Currency table | TCU0 : CUR | CUR | BUD - BUD | Budget table | BUD0 : LEDTYP + BUD + CPY + FCY + VCR + ACC + CCE1 + CCE2 + CCE3
# BUC - BUDFORCAL | Budget calculation formula | BUC0 : BUDFOR + LIN | BUDFOR | BVC - BUDVARCAL | Budget calculation variable | BVC0 : BUDFOR + VARCOD
# BVC - BUDVARCAL | Budget calculation variable | BVC0 : BUDFOR + VARCOD | FCY | CPY - COMPANY | Company | CPY0 : CPY
# CPY - COMPANY | Company | CPY0 : CPY | FCY | FCY - FACILITY | Sites | FCY0 : FCY
# BUP - BUDPAR | Budget setup | BUP0 : BUD | BUD | BUD - BUD | Budget table | BUD0 : LEDTYP + BUD + CPY + FCY + VCR + ACC + CCE1 + CCE2 + CCE3
# BUD - BUD | Budget table | BUD0 : LEDTYP + BUD + CPY + FCY + VCR + ACC + CCE1 + CCE2 + CCE3 | AX12:CCE2, AX13:CCE3, COA:ACC | CCE - CACCE | Dimensions | CCE0 : DIE + CCE
# COA - GCOA | Chart of accounts | COA0 : COA | ACC | GAC - GACCOUNT | Accounts | GAC0 : COA + ACC
# CCE - CACCE | Dimensions | CCE0 : DIE + CCE | DIE | DIE - GDIE | Dimension types | DIE0 : DIE
# GYM - GACCPYM | Account pyramids | GYM0 : PYM | PYMACC | CYY - GCCEPYM | Dimension pyramids | CYY0 : PYM
# CYY - GCCEPYM | Dimension pyramids | CYY0 : PYM | PYMACC | GYM - GACCPYM | Account pyramids | GYM0 : PYM
# TCU - TABCUR | Currency table | TCU0 : CUR | - | - | - | -
# BUC - BUDFORCAL | Budget calculation formula | BUC0 : BUDFOR + LIN | BUDFOR | BVC - BUDVARCAL | Budget calculation variable | BVC0 : BUDFOR + VARCOD
# BVC - BUDVARCAL | Budget calculation variable | BVC0 : BUDFOR + VARCOD | FCY | FCY - FACILITY | Sites | FCY0 : FCY
# CPY - COMPANY | Company | CPY0 : CPY | LEGCPY | FCY - FACILITY | Sites | FCY0 : FCY
# FCY - FACILITY | Sites | FCY0 : FCY | - | - | - | -
# BUP - BUDPAR | Budget setup | BUP0 : BUD | BUD | BUD - BUD | Budget table | BUD0 : LEDTYP + BUD + CPY + FCY + VCR + ACC + CCE1 + CCE2 + CCE3
# BUD - BUD | Budget table | BUD0 : LEDTYP + BUD + CPY + FCY + VCR + ACC + CCE1 + CCE2 + CCE3 | BUD, FCY, AX12:CCE2, AX13:CCE3, AX14:DIE, COA:ACC | BUP - BUDPAR, FCY - FACILITY, CCE - CACCE, DIE - GDIE, COA - GCOA | Budget setup, Sites, Dimensions, Dimension types, Chart of accounts | BUP0 : BUD, FCY0 : FCY, CCE0 : DIE + CCE, DIE0 : DIE, COA0 : COA
# GYM - GACCPYM | Account pyramids | GYM0 : PYM | PYMACC | CYY - GCCEPYM | Dimension pyramids | CYY0 : PYM
# CYY - GCCEPYM | Dimension pyramids | CYY0 : PYM | PYMACC, PYMCE | GYM - GACCPYM, CCE - CACCE | Account pyramids, Dimensions | GYM0 : PYM, CCE0 : DIE + CCE
# CCE - CACCE | Dimensions | CCE0 : DIE + CCE | DIE, AX12:OCE2, AX13:OCE3, COA:ACC | DIE - GDIE, COA - GCOA | Dimension types, Chart of accounts | DIE0 : DIE, COA0 : COA
# COA - GCOA | Chart of accounts | COA0 : COA | ACC | GAC - GACCOUNT | Accounts | GAC0 : COA + ACC
# GAC - GACCOUNT | Accounts | GAC0 : COA + ACC | - | - | - | -
# DIE - GDIE | Dimension types | DIE0 : DIE | - | - | - | -' metadata={'h1': 'ACCOUNTING 4 - BUDGETS', 'source': 'X3_RELATIONSHIPS.md'}
#
#
# --------------------------------------------------
#
#
# Docs retrieved from vectorstore :
#
# page_content='Utilisation : Réactive les zones spécifiées, les rendant à nouveau saisissables.
# Exemple :
# «Actzo [M:SOH0] SOHNUM»' metadata={'h1': 'Manipulation des Écrans dans Sage X3', 'h2': 'Dégrisage des Zones (ACTZO)', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='«# Déclaration du sous-programme
# Subprog ZDAT (DAT,ZERR)
# Value date DAT
# Variable integer ZERR
# If DAT > date$ : ZERR = 1 : Endif
# End' metadata={'h1': 'Code to execute when the label is called', 'h2': 'Les Sous-programmes', 'h3': 'Syntaxe et Exemple:', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='#If [F:SOH]SOHCAT=4 & ([F:SOH]BETFCY=2 | [F:SOC]PLI<>"")
# Call CLCNETPRI([M:SDH1]QTY(NOL),[M:SDH1]CUR, NOL)From TRTVENPRI
# #Endif
# Call CLCPFM([M:SDH0]STOFCY,[M:SDH1]PRITYP,[M:SDH0]CHGTYP,[M:SDH1]SHIDAT,
# & [M:SDH1]CUR,NOL,1) From TRTVENPRI
# Call APRES\_LIGNE(NOL,0) From SUBSDHB
# #--CPO 79343
# If GIMPORT=0 and GREP<>"C" and GSDHSUPPLIGDSP<>999999
# Local Integer WTEMPDSP : Raz WTEMPDSP
# Call CTLSUPP\_EXISTDSP("SDH",NOL,WTEMPDSP) From TRTVENDIV
# If WTEMPDSP=1
# GSDHSUPPLIGDSP +=1
# Endif
# Endif
# #--/CPO
# GNETMAR=1
# Raz GOUVSOR
# nolign = NOL+1' metadata={'h1': '(Si frais/remise dépendant de la qté (par ligne) et plusieurs liv.,le prix net doit être le même sur chaque liv.)', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Pour indiquer l'avancement d'une opération prolongée.
# Syntaxe:
# «Call TEMPON("Action en cours...0%") From GESECRAN' metadata={'h1': 'Gestion des Boîtes de Dialogue dans Sage X3', 'h2': "Messages Progressifs et d'Attente", 'h3': 'Message Progressif (Progressive waiting message):', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Avec la version 5 de Sage X3, les CLOBs sont traités de manière encore plus intégrée, comme des chaînes de caractères standards. Cette amélioration permet d'utiliser toutes les instructions normales de manipulation de chaînes sur des CLOBs, simplifiant le code et rendant les scripts plus lisibles.
# Conclusion
# La gestion des BLOBs et CLOBs dans Sage X3 fournit une flexibilité essentielle pour les applications qui nécessitent une manipulation intensive de données textuelles ou binaires. Que ce soit pour stocker des documents, gérer de grands ensembles de données ou réaliser des opérations complexes sur des textes volumineux, les fonctionnalités L4G de Sage X3 rendent ces tâches efficaces et gérables.
# Dans l'environnement Sage X3, la manipulation des blocs tableaux sur les écrans est une tâche commune pour les développeurs qui cherchent à gérer et présenter des données de manière structurée et interactive. La gestion des variables dans un contexte de bloc tableau est particulièrement importante, car elle permet de dynamiser les interactions avec les données de l'ERP. Cet article explore comment les variables et la méthode Trans-Classe sont utilisées pour gérer efficacement les données dans les blocs tableaux d’un écran Sage X3.' metadata={'h1': 'Assigner les valeurs de la table aux champs du masque : 2nde solution', 'h2': 'Gestion des CLOBs dans Sage X3', 'h3': 'Avantages des CLOBs en Version 5', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='| Fonction | Description |
# | --- | --- |
# | abs(nombre) | Valeur absolue de nombre. |
# | mod(ientier, idiv) | Modulo entre ientier et idiv. |
# | rnd(nombre) | Génère un nombre aléatoire entre 0 et nombre. |
# | sgn(nombre) | Retourne le signe de nombre. |
# | sqr(nombre) | Calcule la racine carrée de nombre. |
# | ar2(nombre) | Arrondi de nombre à 2 décimales. |
# | arr(nombre, nprec) | Arrondi de nombre à nprec décimales près. |
# | fix(nombre) | Troncature de nombre. |
# | int(nombre) | Partie entière de nombre. |
# | fac(ientier) | Factorielle de ientier. |
# | anp(in, ip) | Arrangements de ip dans in. |
# | cnp(in, ip) | Combinaisons de ip dans in. |
# | Format$ | Mise en forme d’un nombre. |' metadata={'h1': 'Les fonctions L4G de manipulations de variables', 'h2': 'Fonctions pour les Expressions Numériques', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='«Local char TIT(30) : [L]TIT = ‘Formation langage’
# If !GSERVEUR : Call OUVRE\_TRACE(TIT) From LECFIC : Endif
# …
# If !GSERVEUR : Call FERME\_TRACE From LECFIC : Endif »' metadata={'h1': 'Gestion des Traces dans Sage X3', 'h2': 'Concepts de Base', 'h3': "Exemple d'ouverture et de fermeture :", 'source': 'Sage X3 L4G.md'}
#
#
# page_content='Utilisation : Rend les zones spécifiées non saisissables et visuellement grises.
# Exemple :
# «Grizo [M:SOH0] SOHNUM»' metadata={'h1': 'Manipulation des Écrans dans Sage X3', 'h2': 'Grisage des Zones (GRIZO)', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='| Fonction | Description |
# | --- | --- |
# | date$ | Retourne la date du jour (Serveur). |
# | time$ | Retourne l’heure courante sous la forme HH:MM:SS. |
# | time | Heure courante en secondes. |
# | day(date) | Extrait le jour d’une date. |
# | day$(date) | Retourne le nom du jour d’une date. |
# | month(date) | Extrait le mois d’une date. |
# | month$(date) | Retourne le nom du mois d’une date. |
# | year(date) | Extrait l’année d’une date. |
# | gdat$(ijour, imois, iannée) | Retourne la date correspondant à [ijour/imois/iannée]. |
# | nday(date) | Retourne le nombre de jours depuis le 1/1/1600 de date. |
# | nday$(inbjour) | Convertit un nombre de jours depuis le 1/1/1600 en date. |
# | dayn(date) | Retourne le numéro de jour dans la semaine de date. |
# | week(date) | Retourne le numéro de semaine d’une date. |
# | aweek(isemaine, iannée) | Date du début de la semaine numéro isemaine de iannée. |
# | eomonth(date) | Retourne la date de la fin du mois d’une date. |
# | addmonth(date, inb) | Ajoute inb mois à une date. |
# | format$ | Mise en forme d’une date. |' metadata={'h1': 'Les fonctions L4G de manipulations de variables', 'h2': 'Fonctions pour les Dates', 'source': 'Sage X3 L4G.md'}
#
#
# page_content='[M:SDH1]WSTOSEQ(NOL) = [L]WSTOSEQ' metadata={'h1': 'Récupération du lien entre ligne document et écran travail', 'source': 'Sage X3 L4G.md'}
#
#
# --------------------------------------------------
